# %% [markdown]
# <h1><font size="6" color="green"><b> LightAutoML in Titanic: </b></font></h1>
#
# <h2><font size="4" color="blue"><b> 80% accuracy in several lines of code </b></font></h2>
#
# Tutorial for improve skills: 'LightAutoML vs Titanic: 80% accuracy in several lines of code' (from Alexander Ryzhkov) by Marcus Mariano
#
# **For more information about Marcus Mariano: [Web site](https://marcusmariano.github.io/mmariano/)**
#
# **LightAutoML vs Titanic: 80% accuracy in several lines of code: [Alexander Ryzhkov](https://towardsdatascience.com/lightautoml-preset-usage-tutorial-2cce7da6f936)**
#
#
# **LightAutoML - automatic model creation framework: [LightAutoML](https://github.com/sberbank-ai-lab/LightAutoML)**

# %% [markdown]
# # Import Packages

# %%
import pandas as pd
import numpy as np

from tqdm.notebook import tqdm

from matplotlib import pyplot as plt
import seaborn as sns

sns.set(style="darkgrid", color_codes=True)
# %matplotlib inline

# Standard python libraries
import os
import time
import re

# Installed libraries
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import train_test_split

# Imports from LightAutoML package
from lightautoml.automl.presets.tabular_presets import TabularAutoML, TabularUtilizedAutoML
from lightautoml.tasks import Task

# %% [markdown]
# # Datasets load

# %%
# %%time

data = pd.read_csv('data/train.csv')
print(data.shape)
data.head()
# Out:
# (891, 12)
# Wall time: 17 ms
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test = pd.read_csv('data/test.csv')
print(test.shape)
test.head()
# Out:
# (418, 11)
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# !ls ./data/
# Out:
# gender_submission.csv
# test.csv
# train.csv

# %%
submission = pd.read_csv('data/gender_submission.csv')
print(submission.shape)
submission.head()
# Out:
# (418, 2)
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# # Additional expert features creation block

# %%
train_data = data.copy()
test_data = test.copy()

def get_title(name):
    title_search = re.search(' ([A-Za-z]+)\.', name)
    # If the title exists, extract and return it.
    if title_search:
        return title_search.group(1)
    return ""

def create_extra_features(data):
    data['Ticket_type'] = data['Ticket'].map(lambda x: x[0:3])
    data['Name_Words_Count'] = data['Name'].map(lambda x: len(x.split()))
    data['Has_Cabin'] = data["Cabin"].map(lambda x: 1 - int(type(x) == float))
    data['FamilySize'] = data['SibSp'] + data['Parch'] + 1
    
    data['CategoricalFare'] = pd.qcut(data['Fare'], 5).astype(str)
    data['CategoricalAge'] = pd.cut(data['Age'], 5).astype(str)
    
    data['Title'] = data['Name'].apply(get_title).replace(['Lady', 'Countess','Capt', 
                                                           'Col','Don', 'Dr', 'Major', 
                                                           'Rev', 'Sir', 'Jonkheer', 
                                                           'Dona'], 'Rare')
    data['Title'] = data['Title'].replace('Mlle', 'Miss')
    data['Title'] = data['Title'].replace('Ms', 'Miss')
    data['Title'] = data['Title'].replace('Mme', 'Mrs')
    data['Title'] = data['Title'].map({"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, 
                                       "Rare": 5}).fillna(0)
    
    return data



train_data = create_extra_features(train_data)
test_data = create_extra_features(test_data)

print(train_data.shape, test_data.shape)
train_data.head()
# Out:
# (891, 19) (418, 18)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Ticket_type  \
# 0      0         A/5 21171   7.2500   NaN        S         A/5
# 1      0          PC 17599  71.2833   C85        C         PC
# 2      0  STON/O2. 3101282   7.9250   NaN        S         STO
# 3      0            113803  53.1000  C123        S         113
# 4      0            373450   8.0500   NaN        S         373
#
#    Name_Words_Count  Has_Cabin  FamilySize    CategoricalFare  \
# 0                 4          0           2    (-0.001, 7.854]
# 1                 7          1           2  (39.688, 512.329]
# 2                 3          0           1      (7.854, 10.5]
# 3                 7          1           2  (39.688, 512.329]
# 4                 4          0           1      (7.854, 10.5]
#
#      CategoricalAge  Title
# 0  (16.336, 32.252]      1
# 1  (32.252, 48.168]      3
# 2  (16.336, 32.252]      2
# 3  (32.252, 48.168]      3
# 4  (32.252, 48.168]      1

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_data.isnull().sum()
# Out:
# PassengerId           0
# Survived              0
# Pclass                0
# Name                  0
# Sex                   0
# Age                 177
# SibSp                 0
# Parch                 0
# Ticket                0
# Fare                  0
# Cabin               687
# Embarked              2
# Ticket_type           0
# Name_Words_Count      0
# Has_Cabin             0
# FamilySize            0
# CategoricalFare       0
# CategoricalAge        0
# Title                 0
# dtype: int64

# %% [markdown]
# # Division of training, validation and testing databases

# %%
# %%time

# Database division into training and testing.
from sklearn.model_selection import train_test_split

SEED = 0

# Separation of data into a training set and a test set
df_train, df_valid = train_test_split(train_data, 
                                      test_size = 0.2, 
                                      stratify = data["Survived"], 
                                      random_state = SEED)

print(f"Parts sizes: df_train = {df_train.shape}, df_valid = {df_valid.shape}")
# Out:
# Parts sizes: df_train = (712, 19), df_valid = (179, 19)
# Wall time: 27 ms

# %%
# logging.info("Parts sizes: tr_data = {}, valid_data = {}".format(tr_data.shape, 
#                                                                  valid_data.shape))

# %% [markdown]
# # LightAutoML preset usage
#
# ## Create Task object
#
#     ‘binary’ for binary classification
#     ‘reg’ for regression and
#     ‘multiclass’ for multiclass classification

# %%
def f1_metric(y_true, y_pred):
    return f1_score(y_true, (y_pred > 0.5).astype(int))

task = Task('binary', metric = f1_metric)

# %% [markdown]
# ## Setup columns roles

# %%
roles = {'target': 'Survived',
         'drop': ['PassengerId', 'Name', 'Ticket']}

# %% [markdown]
# ## Create AutoML model from preset

# %%
# !cat /proc/cpuinfo

# %%
# !lscpu
# Out:
# 'lscpu' nÆo ‚ reconhecido como um comando interno
# ou externo, um programa oper vel ou um arquivo em lotes.

# %%
automl = TabularAutoML(task = task, 
                       timeout = 250, # 600 seconds = 10 minutes
                       memory_limit = 6, # Optimal run for your pc
                       cpu_limit = 4, # Optimal CPU for your pc
                       general_params = {'use_algos': [['linear_l2', 
                                         'lgb', 'lgb_tuned']]})

# %% [markdown]
# __Out-of-Fold (OOF for short) predictions__

# %%
oof_pred = automl.fit_predict(df_train, roles = roles)
# Out:
# Start automl preset with listed constraints:
# - time: 600 seconds
# - cpus: 4 cores
# - memory: 4 gb
#
# Train data shape: (712, 19)
# Feats was rejected during automatic roles guess: []
#
#
# Layer 1 ...
# Train process start. Time left 599.5820004940033 secs
# Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = 0.0
# Linear model: C = 5e-05 score = 0.0
# Linear model: C = 0.0001 score = 0.25396825396825395
# Linear model: C = 0.0005 score = 0.5432098765432098
# Linear model: C = 0.001 score = 0.6170212765957446
# Linear model: C = 0.005 score = 0.7216494845360825
# Linear model: C = 0.01 score = 0.7272727272727274
# Linear model: C = 0.05 score = 0.7722772277227722
# Linear model: C = 0.1 score = 0.7599999999999999
# Linear model: C = 0.5 score = 0.764705882352941
#
# ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = 0.0
# Linear model: C = 5e-05 score = 0.0
# Linear model: C = 0.0001 score = 0.16666666666666669
# Linear model: C = 0.0005 score = 0.5747126436781609
# Linear model: C = 0.001 score = 0.6153846153846153
# Linear model: C = 0.005 score = 0.7400000000000001
# Linear model: C = 0.01 score = 0.7524752475247525
# Linear model: C = 0.05 score = 0.780952380952381
# Linear model: C = 0.1 score = 0.761904761904762
# Linear model: C = 0.5 score = 0.7692307692307693
#
# ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = 0.0
# Linear model: C = 5e-05 score = 0.0
# Linear model: C = 0.0001 score = 0.22950819672131148
# Linear model: C = 0.0005 score = 0.651685393258427
# Linear model: C = 0.001 score = 0.7216494845360826
# Linear model: C = 0.005 score = 0.7547169811320754
# Linear model: C = 0.01 score = 0.7476635514018692
# Linear model: C = 0.05 score = 0.7636363636363638
# Linear model: C = 0.1 score = 0.7636363636363638
# Linear model: C = 0.5 score = 0.7289719626168224
#
# ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = 0.0
# Linear model: C = 5e-05 score = 0.0
# Linear model: C = 0.0001 score = 0.25806451612903225
# Linear model: C = 0.0005 score = 0.6595744680851063
# Linear model: C = 0.001 score = 0.6732673267326733
# Linear model: C = 0.005 score = 0.7184466019417475
# Linear model: C = 0.01 score = 0.7254901960784315
# Linear model: C = 0.05 score = 0.7254901960784315
# Linear model: C = 0.1 score = 0.7307692307692308
# Linear model: C = 0.5 score = 0.7115384615384615
# Linear model: C = 1 score = 0.7115384615384615
#
# ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = 0.0
# Linear model: C = 5e-05 score = 0.0
# Linear model: C = 0.0001 score = 0.25396825396825395
# Linear model: C = 0.0005 score = 0.7450980392156863
# Linear model: C = 0.001 score = 0.7339449541284404
# Linear model: C = 0.005 score = 0.8
# Linear model: C = 0.01 score = 0.8070175438596492
# Linear model: C = 0.05 score = 0.8256880733944955
# Linear model: C = 0.1 score = 0.8333333333333334
# Linear model: C = 0.5 score = 0.8333333333333334
# Linear model: C = 1 score = 0.8148148148148149
# Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# Time left 595.4007930755615
# Start fitting Selector_LightGBM ...
#
# ===== Start working with fold 0 for Selector_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.483864	valid's Opt metric: 0.651163
# [200]	valid's binary_logloss: 0.440242	valid's Opt metric: 0.681319
# [300]	valid's binary_logloss: 0.427584	valid's Opt metric: 0.709677
# [400]	valid's binary_logloss: 0.419639	valid's Opt metric: 0.715789
# [500]	valid's binary_logloss: 0.419349	valid's Opt metric: 0.729167
# [600]	valid's binary_logloss: 0.416896	valid's Opt metric: 0.742268
# [700]	valid's binary_logloss: 0.419198	valid's Opt metric: 0.742268
# Early stopping, best iteration is:
# [509]	valid's binary_logloss: 0.418837	valid's Opt metric: 0.742268
# Selector_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.468624	valid's Opt metric: 0.688889
# [200]	valid's binary_logloss: 0.422113	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.408388	valid's Opt metric: 0.77551
# [400]	valid's binary_logloss: 0.40912	valid's Opt metric: 0.762887
# Early stopping, best iteration is:
# [250]	valid's binary_logloss: 0.412818	valid's Opt metric: 0.77551
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.473924	valid's Opt metric: 0.694737
# [200]	valid's binary_logloss: 0.42674	valid's Opt metric: 0.701031
# [300]	valid's binary_logloss: 0.411062	valid's Opt metric: 0.74
# [400]	valid's binary_logloss: 0.408399	valid's Opt metric: 0.764706
# [500]	valid's binary_logloss: 0.406048	valid's Opt metric: 0.757282
# [600]	valid's binary_logloss: 0.404512	valid's Opt metric: 0.769231
# [700]	valid's binary_logloss: 0.401329	valid's Opt metric: 0.757282
# Early stopping, best iteration is:
# [537]	valid's binary_logloss: 0.40482	valid's Opt metric: 0.769231
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.46077	valid's Opt metric: 0.77551
# [200]	valid's binary_logloss: 0.408926	valid's Opt metric: 0.776699
# [300]	valid's binary_logloss: 0.394026	valid's Opt metric: 0.761905
# Early stopping, best iteration is:
# [103]	valid's binary_logloss: 0.457719	valid's Opt metric: 0.787879
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.49304	valid's Opt metric: 0.6875
# [200]	valid's binary_logloss: 0.461472	valid's Opt metric: 0.718447
# [300]	valid's binary_logloss: 0.457412	valid's Opt metric: 0.72549
# Early stopping, best iteration is:
# [181]	valid's binary_logloss: 0.46426	valid's Opt metric: 0.732673
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.436706	valid's Opt metric: 0.804124
# [200]	valid's binary_logloss: 0.368916	valid's Opt metric: 0.838095
# [300]	valid's binary_logloss: 0.343696	valid's Opt metric: 0.836364
# [400]	valid's binary_logloss: 0.335899	valid's Opt metric: 0.828829
# Early stopping, best iteration is:
# [227]	valid's binary_logloss: 0.359237	valid's Opt metric: 0.851852
# Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Optuna may run 485.6718020439148 secs
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.457105	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.420678	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.412889	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.415049	valid's Opt metric: 0.76
# [500]	valid's binary_logloss: 0.428413	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [336]	valid's binary_logloss: 0.411273	valid's Opt metric: 0.755102
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.488304	valid's Opt metric: 0.666667
# [200]	valid's binary_logloss: 0.429544	valid's Opt metric: 0.717391
# [300]	valid's binary_logloss: 0.411774	valid's Opt metric: 0.757895
# [400]	valid's binary_logloss: 0.404875	valid's Opt metric: 0.762887
# [500]	valid's binary_logloss: 0.404798	valid's Opt metric: 0.762887
# Early stopping, best iteration is:
# [311]	valid's binary_logloss: 0.410864	valid's Opt metric: 0.770833
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466349	valid's Opt metric: 0.723404
# [200]	valid's binary_logloss: 0.418249	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.412369	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.413927	valid's Opt metric: 0.787879
# [500]	valid's binary_logloss: 0.420235	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [370]	valid's binary_logloss: 0.410465	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.461124	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.419505	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.413779	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.417196	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.430463	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [330]	valid's binary_logloss: 0.411555	valid's Opt metric: 0.767677
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465599	valid's Opt metric: 0.73913
# [200]	valid's binary_logloss: 0.420179	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.412154	valid's Opt metric: 0.75
# [400]	valid's binary_logloss: 0.416218	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.422165	valid's Opt metric: 0.767677
# Early stopping, best iteration is:
# [322]	valid's binary_logloss: 0.411057	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.494358	valid's Opt metric: 0.681818
# [200]	valid's binary_logloss: 0.449343	valid's Opt metric: 0.725275
# [300]	valid's binary_logloss: 0.433384	valid's Opt metric: 0.73913
# [400]	valid's binary_logloss: 0.425075	valid's Opt metric: 0.73913
# Early stopping, best iteration is:
# [290]	valid's binary_logloss: 0.43415	valid's Opt metric: 0.73913
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.46173	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.42425	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.414422	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.413625	valid's Opt metric: 0.76
# [500]	valid's binary_logloss: 0.42551	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [364]	valid's binary_logloss: 0.412687	valid's Opt metric: 0.767677
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.472062	valid's Opt metric: 0.711111
# [200]	valid's binary_logloss: 0.41924	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.408323	valid's Opt metric: 0.757895
# [400]	valid's binary_logloss: 0.408074	valid's Opt metric: 0.770833
# [500]	valid's binary_logloss: 0.414602	valid's Opt metric: 0.77551
# Early stopping, best iteration is:
# [326]	valid's binary_logloss: 0.406649	valid's Opt metric: 0.757895
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.471952	valid's Opt metric: 0.696629
# [200]	valid's binary_logloss: 0.423378	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.409864	valid's Opt metric: 0.736842
# [400]	valid's binary_logloss: 0.404708	valid's Opt metric: 0.736842
# Early stopping, best iteration is:
# [242]	valid's binary_logloss: 0.415882	valid's Opt metric: 0.736842
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.467566	valid's Opt metric: 0.711111
# [200]	valid's binary_logloss: 0.421305	valid's Opt metric: 0.762887
# [300]	valid's binary_logloss: 0.412806	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.416737	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.420544	valid's Opt metric: 0.767677
# Early stopping, best iteration is:
# [301]	valid's binary_logloss: 0.412878	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.46555	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.420424	valid's Opt metric: 0.762887
# [300]	valid's binary_logloss: 0.409716	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.411552	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.42104	valid's Opt metric: 0.792079
# Early stopping, best iteration is:
# [371]	valid's binary_logloss: 0.408171	valid's Opt metric: 0.783505
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464795	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.421297	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.413353	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.414189	valid's Opt metric: 0.767677
# [500]	valid's binary_logloss: 0.420422	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [381]	valid's binary_logloss: 0.412174	valid's Opt metric: 0.767677
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.469244	valid's Opt metric: 0.725275
# [200]	valid's binary_logloss: 0.423336	valid's Opt metric: 0.731183
# [300]	valid's binary_logloss: 0.414086	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.415928	valid's Opt metric: 0.762887
# Early stopping, best iteration is:
# [222]	valid's binary_logloss: 0.419189	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465023	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.420662	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.410365	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.414641	valid's Opt metric: 0.784314
# [500]	valid's binary_logloss: 0.42251	valid's Opt metric: 0.792079
# Early stopping, best iteration is:
# [348]	valid's binary_logloss: 0.409166	valid's Opt metric: 0.767677
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.463063	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.422365	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.415012	valid's Opt metric: 0.75
# Early stopping, best iteration is:
# [140]	valid's binary_logloss: 0.438203	valid's Opt metric: 0.75
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466986	valid's Opt metric: 0.723404
# [200]	valid's binary_logloss: 0.41939	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.411011	valid's Opt metric: 0.75
# [400]	valid's binary_logloss: 0.414926	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.420762	valid's Opt metric: 0.76
# Early stopping, best iteration is:
# [312]	valid's binary_logloss: 0.409659	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464961	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.420391	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.41216	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.412525	valid's Opt metric: 0.792079
# [500]	valid's binary_logloss: 0.418992	valid's Opt metric: 0.8
# [600]	valid's binary_logloss: 0.429463	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [413]	valid's binary_logloss: 0.411273	valid's Opt metric: 0.792079
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.462632	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.421159	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.414641	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.419284	valid's Opt metric: 0.767677
# [500]	valid's binary_logloss: 0.424559	valid's Opt metric: 0.784314
# Early stopping, best iteration is:
# [333]	valid's binary_logloss: 0.413341	valid's Opt metric: 0.755102
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465032	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.422935	valid's Opt metric: 0.709677
# [300]	valid's binary_logloss: 0.415491	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.416651	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.423063	valid's Opt metric: 0.792079
# Early stopping, best iteration is:
# [314]	valid's binary_logloss: 0.413841	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.462005	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.419707	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.41332	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.415888	valid's Opt metric: 0.767677
# [500]	valid's binary_logloss: 0.42421	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [321]	valid's binary_logloss: 0.412112	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466612	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.430969	valid's Opt metric: 0.709677
# [300]	valid's binary_logloss: 0.421234	valid's Opt metric: 0.736842
# [400]	valid's binary_logloss: 0.419377	valid's Opt metric: 0.75
# [500]	valid's binary_logloss: 0.420272	valid's Opt metric: 0.75
# Early stopping, best iteration is:
# [317]	valid's binary_logloss: 0.420492	valid's Opt metric: 0.75
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464079	valid's Opt metric: 0.681319
# [200]	valid's binary_logloss: 0.418606	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.410046	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.412609	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [296]	valid's binary_logloss: 0.409284	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.462604	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.422043	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.413146	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.416475	valid's Opt metric: 0.767677
# [500]	valid's binary_logloss: 0.424618	valid's Opt metric: 0.77551
# Early stopping, best iteration is:
# [308]	valid's binary_logloss: 0.412767	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.462979	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.419776	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.411731	valid's Opt metric: 0.77551
# [400]	valid's binary_logloss: 0.418387	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.423106	valid's Opt metric: 0.8
# Early stopping, best iteration is:
# [317]	valid's binary_logloss: 0.41068	valid's Opt metric: 0.767677
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465747	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.422964	valid's Opt metric: 0.709677
# [300]	valid's binary_logloss: 0.411377	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.41446	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [298]	valid's binary_logloss: 0.411178	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.461365	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.418982	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.413053	valid's Opt metric: 0.75
# [400]	valid's binary_logloss: 0.415145	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.42226	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [321]	valid's binary_logloss: 0.411215	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466658	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.423033	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.413998	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.415384	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.422771	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [371]	valid's binary_logloss: 0.412322	valid's Opt metric: 0.787879
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464949	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.421811	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.411422	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.412849	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.418257	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [378]	valid's binary_logloss: 0.409507	valid's Opt metric: 0.787879
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465737	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.423134	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.411611	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.413551	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.41985	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [371]	valid's binary_logloss: 0.409777	valid's Opt metric: 0.787879
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466963	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.418471	valid's Opt metric: 0.762887
# [300]	valid's binary_logloss: 0.409031	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.412079	valid's Opt metric: 0.762887
# Early stopping, best iteration is:
# [295]	valid's binary_logloss: 0.408629	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.46602	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.422	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.414595	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.414996	valid's Opt metric: 0.792079
# [500]	valid's binary_logloss: 0.421836	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [370]	valid's binary_logloss: 0.411768	valid's Opt metric: 0.767677
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.46804	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.423526	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.414606	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.41704	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.425058	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [351]	valid's binary_logloss: 0.413623	valid's Opt metric: 0.787879
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466676	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.423197	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.413344	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.417075	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.421215	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [305]	valid's binary_logloss: 0.412013	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465537	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.422991	valid's Opt metric: 0.709677
# [300]	valid's binary_logloss: 0.413209	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.416171	valid's Opt metric: 0.792079
# Early stopping, best iteration is:
# [295]	valid's binary_logloss: 0.412573	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466447	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.418845	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.409926	valid's Opt metric: 0.77551
# [400]	valid's binary_logloss: 0.409738	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.415406	valid's Opt metric: 0.772277
# Early stopping, best iteration is:
# [378]	valid's binary_logloss: 0.408303	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466023	valid's Opt metric: 0.731183
# [200]	valid's binary_logloss: 0.420751	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.412972	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.413492	valid's Opt metric: 0.77551
# Early stopping, best iteration is:
# [276]	valid's binary_logloss: 0.411461	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.467092	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.422563	valid's Opt metric: 0.709677
# [300]	valid's binary_logloss: 0.411552	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.411165	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.417438	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [384]	valid's binary_logloss: 0.408856	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464457	valid's Opt metric: 0.723404
# [200]	valid's binary_logloss: 0.418156	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.409816	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.412846	valid's Opt metric: 0.77551
# Early stopping, best iteration is:
# [245]	valid's binary_logloss: 0.411676	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464922	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.420617	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.410004	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.411562	valid's Opt metric: 0.792079
# [500]	valid's binary_logloss: 0.418327	valid's Opt metric: 0.8
# Early stopping, best iteration is:
# [370]	valid's binary_logloss: 0.40762	valid's Opt metric: 0.767677
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466441	valid's Opt metric: 0.725275
# [200]	valid's binary_logloss: 0.42245	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.412123	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.416122	valid's Opt metric: 0.762887
# Early stopping, best iteration is:
# [258]	valid's binary_logloss: 0.413359	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.4653	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.422344	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.413487	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.413795	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [295]	valid's binary_logloss: 0.412682	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465013	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.421378	valid's Opt metric: 0.709677
# [300]	valid's binary_logloss: 0.413165	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.410788	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.418191	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [350]	valid's binary_logloss: 0.411462	valid's Opt metric: 0.787879
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465605	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.418033	valid's Opt metric: 0.762887
# [300]	valid's binary_logloss: 0.408007	valid's Opt metric: 0.77551
# [400]	valid's binary_logloss: 0.409688	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [271]	valid's binary_logloss: 0.41003	valid's Opt metric: 0.787879
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.467009	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.420878	valid's Opt metric: 0.762887
# [300]	valid's binary_logloss: 0.411013	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.411767	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.418929	valid's Opt metric: 0.772277
# Early stopping, best iteration is:
# [371]	valid's binary_logloss: 0.409414	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.467678	valid's Opt metric: 0.731183
# [200]	valid's binary_logloss: 0.421339	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.40954	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.411699	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.420774	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [329]	valid's binary_logloss: 0.407239	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.463473	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.419977	valid's Opt metric: 0.709677
# [300]	valid's binary_logloss: 0.409214	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.415369	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.422303	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [302]	valid's binary_logloss: 0.408757	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.46562	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.419776	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.409358	valid's Opt metric: 0.75
# [400]	valid's binary_logloss: 0.409378	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.414629	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [378]	valid's binary_logloss: 0.407037	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.500146	valid's Opt metric: 0.681818
# [200]	valid's binary_logloss: 0.446157	valid's Opt metric: 0.73913
# [300]	valid's binary_logloss: 0.424556	valid's Opt metric: 0.73913
# [400]	valid's binary_logloss: 0.413966	valid's Opt metric: 0.736842
# [500]	valid's binary_logloss: 0.408329	valid's Opt metric: 0.77551
# [600]	valid's binary_logloss: 0.405026	valid's Opt metric: 0.77551
# Early stopping, best iteration is:
# [499]	valid's binary_logloss: 0.408416	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.4683	valid's Opt metric: 0.717391
# [200]	valid's binary_logloss: 0.418652	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.41044	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.410689	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.416467	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [387]	valid's binary_logloss: 0.40864	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.467485	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.423243	valid's Opt metric: 0.709677
# [300]	valid's binary_logloss: 0.414481	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.415095	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.423421	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [326]	valid's binary_logloss: 0.411913	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465088	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.420521	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.410835	valid's Opt metric: 0.77551
# [400]	valid's binary_logloss: 0.413701	valid's Opt metric: 0.767677
# [500]	valid's binary_logloss: 0.419683	valid's Opt metric: 0.8
# Early stopping, best iteration is:
# [331]	valid's binary_logloss: 0.409468	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465771	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.425067	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.413814	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.415133	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [294]	valid's binary_logloss: 0.413092	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466972	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.421167	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.414904	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.417592	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [294]	valid's binary_logloss: 0.413944	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464769	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.417998	valid's Opt metric: 0.762887
# [300]	valid's binary_logloss: 0.407842	valid's Opt metric: 0.77551
# [400]	valid's binary_logloss: 0.411921	valid's Opt metric: 0.77551
# Early stopping, best iteration is:
# [252]	valid's binary_logloss: 0.410379	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464731	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.422409	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.413033	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.413555	valid's Opt metric: 0.772277
# Early stopping, best iteration is:
# [263]	valid's binary_logloss: 0.41147	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.46514	valid's Opt metric: 0.703297
# [200]	valid's binary_logloss: 0.422137	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.411768	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.410007	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.415016	valid's Opt metric: 0.77551
# Early stopping, best iteration is:
# [371]	valid's binary_logloss: 0.408072	valid's Opt metric: 0.755102
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466428	valid's Opt metric: 0.725275
# [200]	valid's binary_logloss: 0.41884	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.412015	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.413415	valid's Opt metric: 0.762887
# Early stopping, best iteration is:
# [215]	valid's binary_logloss: 0.416504	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466158	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.4228	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.413259	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.412621	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.417896	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [370]	valid's binary_logloss: 0.410293	valid's Opt metric: 0.767677
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.46135	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.420406	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.413321	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.415361	valid's Opt metric: 0.767677
# [500]	valid's binary_logloss: 0.426503	valid's Opt metric: 0.8
# Early stopping, best iteration is:
# [322]	valid's binary_logloss: 0.412509	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464292	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.420585	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.411312	valid's Opt metric: 0.75
# [400]	valid's binary_logloss: 0.41427	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.417889	valid's Opt metric: 0.767677
# Early stopping, best iteration is:
# [324]	valid's binary_logloss: 0.410117	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464018	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.421814	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.413815	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.417523	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.42351	valid's Opt metric: 0.8
# Early stopping, best iteration is:
# [333]	valid's binary_logloss: 0.412782	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465174	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.42101	valid's Opt metric: 0.709677
# [300]	valid's binary_logloss: 0.411271	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.413333	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.420691	valid's Opt metric: 0.792079
# Early stopping, best iteration is:
# [370]	valid's binary_logloss: 0.409024	valid's Opt metric: 0.78
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464414	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.422097	valid's Opt metric: 0.75
# ...
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.467981	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.423052	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.412733	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.414436	valid's Opt metric: 0.767677
# [500]	valid's binary_logloss: 0.418203	valid's Opt metric: 0.772277
# Early stopping, best iteration is:
# [327]	valid's binary_logloss: 0.412153	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466966	valid's Opt metric: 0.703297
# [200]	valid's binary_logloss: 0.421927	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.411391	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.410835	valid's Opt metric: 0.767677
# [500]	valid's binary_logloss: 0.417252	valid's Opt metric: 0.787879
# [600]	valid's binary_logloss: 0.423439	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [412]	valid's binary_logloss: 0.409776	valid's Opt metric: 0.767677
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.468974	valid's Opt metric: 0.717391
# [200]	valid's binary_logloss: 0.422685	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.41335	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.410686	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.41362	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [364]	valid's binary_logloss: 0.408697	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.469172	valid's Opt metric: 0.725275
# [200]	valid's binary_logloss: 0.423196	valid's Opt metric: 0.757895
# [300]	valid's binary_logloss: 0.412633	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.417007	valid's Opt metric: 0.762887
# [500]	valid's binary_logloss: 0.421507	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [322]	valid's binary_logloss: 0.411945	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465919	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.424512	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.413374	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.413331	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [272]	valid's binary_logloss: 0.411884	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.467526	valid's Opt metric: 0.688889
# [200]	valid's binary_logloss: 0.421516	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.412732	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.414324	valid's Opt metric: 0.762887
# Early stopping, best iteration is:
# [270]	valid's binary_logloss: 0.411141	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466087	valid's Opt metric: 0.717391
# [200]	valid's binary_logloss: 0.419836	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.411706	valid's Opt metric: 0.75
# [400]	valid's binary_logloss: 0.414595	valid's Opt metric: 0.77551
# Early stopping, best iteration is:
# [288]	valid's binary_logloss: 0.41012	valid's Opt metric: 0.75
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464014	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.420895	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.412636	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.410792	valid's Opt metric: 0.792079
# [500]	valid's binary_logloss: 0.418004	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [381]	valid's binary_logloss: 0.409798	valid's Opt metric: 0.767677
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466448	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.421252	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.409648	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.409709	valid's Opt metric: 0.767677
# [500]	valid's binary_logloss: 0.414175	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [314]	valid's binary_logloss: 0.408158	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.467554	valid's Opt metric: 0.703297
# [200]	valid's binary_logloss: 0.42135	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.414124	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.41507	valid's Opt metric: 0.770833
# [500]	valid's binary_logloss: 0.41936	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [322]	valid's binary_logloss: 0.412771	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465413	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.41899	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.408071	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.409592	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.414776	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [303]	valid's binary_logloss: 0.407487	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464019	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.420011	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.411727	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.413431	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [272]	valid's binary_logloss: 0.410529	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466805	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.421569	valid's Opt metric: 0.709677
# [300]	valid's binary_logloss: 0.414487	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.414987	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.421575	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [346]	valid's binary_logloss: 0.413886	valid's Opt metric: 0.787879
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466805	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.421569	valid's Opt metric: 0.709677
# [300]	valid's binary_logloss: 0.414487	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.414987	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.421575	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [346]	valid's binary_logloss: 0.413886	valid's Opt metric: 0.787879
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465921	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.422482	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.415832	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.41759	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.422747	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [364]	valid's binary_logloss: 0.413514	valid's Opt metric: 0.78
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464082	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.421556	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.410804	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.413599	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [291]	valid's binary_logloss: 0.40926	valid's Opt metric: 0.75
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.474318	valid's Opt metric: 0.696629
# [200]	valid's binary_logloss: 0.426176	valid's Opt metric: 0.731183
# [300]	valid's binary_logloss: 0.413702	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.408406	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.407596	valid's Opt metric: 0.77551
# Early stopping, best iteration is:
# [379]	valid's binary_logloss: 0.408752	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.463383	valid's Opt metric: 0.723404
# [200]	valid's binary_logloss: 0.418981	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.409225	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.414586	valid's Opt metric: 0.77551
# Early stopping, best iteration is:
# [294]	valid's binary_logloss: 0.407863	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.46652	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.423233	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.412812	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.411914	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.418323	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [341]	valid's binary_logloss: 0.41259	valid's Opt metric: 0.787879
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465908	valid's Opt metric: 0.717391
# [200]	valid's binary_logloss: 0.423185	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.414198	valid's Opt metric: 0.75
# [400]	valid's binary_logloss: 0.412417	valid's Opt metric: 0.767677
# [500]	valid's binary_logloss: 0.419483	valid's Opt metric: 0.787879
# [600]	valid's binary_logloss: 0.427633	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [412]	valid's binary_logloss: 0.410331	valid's Opt metric: 0.78
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464696	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.41963	valid's Opt metric: 0.762887
# [300]	valid's binary_logloss: 0.410822	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.414091	valid's Opt metric: 0.767677
# Early stopping, best iteration is:
# [297]	valid's binary_logloss: 0.410548	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.42083	valid's Opt metric: 0.76
# Early stopping, best iteration is:
# [66]	valid's binary_logloss: 0.406897	valid's Opt metric: 0.77551
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.398308	valid's Opt metric: 0.75
# Early stopping, best iteration is:
# [72]	valid's binary_logloss: 0.399406	valid's Opt metric: 0.785047
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.407747	valid's Opt metric: 0.789474
# Early stopping, best iteration is:
# [60]	valid's binary_logloss: 0.40154	valid's Opt metric: 0.814159
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.480074	valid's Opt metric: 0.730769
# Early stopping, best iteration is:
# [50]	valid's binary_logloss: 0.444981	valid's Opt metric: 0.737864
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.337548	valid's Opt metric: 0.834783
# Early stopping, best iteration is:
# [38]	valid's binary_logloss: 0.358285	valid's Opt metric: 0.867925
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Time left 377.79156517982483
# Blending: Optimization starts with equal weights and score 0.7683397683397682
# Blending, iter 0: score = 0.7840909090909092, weights = [0.15324706 0.         0.84675294]
# Blending, iter 1: score = 0.7840909090909092, weights = [0.15324706 0.         0.84675294]
# No score update. Terminated
#
# Automl preset training completed in 222.34 seconds.

# %%
222/60
# Out:
# 3.7

# %% [markdown]
# ## Predict to validation data and check scores

# %%
valid_pred = df_valid.copy()

valid_pred = automl.predict(df_valid)

# %%
def acc_score(y_true, y_pred):
    return accuracy_score(y_true, (y_pred > 0.5).astype(int))

print(f"OOF acc: {acc_score(df_train['Survived'].values, oof_pred.data[:, 0])}")
print(f"VAL acc: {acc_score(df_valid['Survived'].values, valid_pred.data[:, 0])}")
# Out:
# OOF acc: 0.8398876404494382
# VAL acc: 0.7988826815642458

# %% [markdown]
# ## Create LightAutoML model with time utilization

# %%
tautoml = TabularUtilizedAutoML(task = task, 
                                timeout = 250, # 600 seconds = 10 minutes
                                memory_limit = 6, # Optimal run for your pc
                                cpu_limit = 4, # Optimal CPU for your pc
                                general_params = {'use_algos': [['linear_l2', 
                                                  'lgb', 'lgb_tuned']]})

oof_pred = tautoml.fit_predict(df_train, roles = roles)
# Out:
# Current random state: {'reader_params': {'random_state': 42}, 'general_params': {'return_all_predictions': False}}
# Found general_params in kwargs, need to combine
# Merged variant for general_params = {'use_algos': [['linear_l2', 'lgb', 'lgb_tuned']], 'return_all_predictions': False}
# Start automl preset with listed constraints:
# - time: 249.99300384521484 seconds
# - cpus: 4 cores
# - memory: 6 gb
#
# Train data shape: (712, 19)
# Feats was rejected during automatic roles guess: []
#
#
# Layer 1 ...
# Train process start. Time left 234.49400234222412 secs
# Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = 0.0
# Linear model: C = 5e-05 score = 0.0
# Linear model: C = 0.0001 score = 0.25396825396825395
# Linear model: C = 0.0005 score = 0.5432098765432098
# Linear model: C = 0.001 score = 0.6170212765957446
# Linear model: C = 0.005 score = 0.7216494845360825
# Linear model: C = 0.01 score = 0.7272727272727274
# Linear model: C = 0.05 score = 0.7722772277227722
# Linear model: C = 0.1 score = 0.7599999999999999
# Linear model: C = 0.5 score = 0.764705882352941
#
# ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = 0.0
# Linear model: C = 5e-05 score = 0.0
# Linear model: C = 0.0001 score = 0.16666666666666669
# Linear model: C = 0.0005 score = 0.5747126436781609
# Linear model: C = 0.001 score = 0.6153846153846153
# Linear model: C = 0.005 score = 0.7400000000000001
# Linear model: C = 0.01 score = 0.7524752475247525
# Linear model: C = 0.05 score = 0.780952380952381
# Linear model: C = 0.1 score = 0.761904761904762
# Linear model: C = 0.5 score = 0.7692307692307693
#
# ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = 0.0
# Linear model: C = 5e-05 score = 0.0
# Linear model: C = 0.0001 score = 0.22950819672131148
# Linear model: C = 0.0005 score = 0.651685393258427
# Linear model: C = 0.001 score = 0.7216494845360826
# Linear model: C = 0.005 score = 0.7547169811320754
# Linear model: C = 0.01 score = 0.7476635514018692
# Linear model: C = 0.05 score = 0.7636363636363638
# Linear model: C = 0.1 score = 0.7636363636363638
# Linear model: C = 0.5 score = 0.7289719626168224
#
# ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = 0.0
# Linear model: C = 5e-05 score = 0.0
# Linear model: C = 0.0001 score = 0.25806451612903225
# Linear model: C = 0.0005 score = 0.6595744680851063
# Linear model: C = 0.001 score = 0.6732673267326733
# Linear model: C = 0.005 score = 0.7184466019417475
# Linear model: C = 0.01 score = 0.7254901960784315
# Linear model: C = 0.05 score = 0.7254901960784315
# Linear model: C = 0.1 score = 0.7307692307692308
# Linear model: C = 0.5 score = 0.7115384615384615
# Linear model: C = 1 score = 0.7115384615384615
#
# ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = 0.0
# Linear model: C = 5e-05 score = 0.0
# Linear model: C = 0.0001 score = 0.25396825396825395
# Linear model: C = 0.0005 score = 0.7450980392156863
# Linear model: C = 0.001 score = 0.7339449541284404
# Linear model: C = 0.005 score = 0.8
# Linear model: C = 0.01 score = 0.8070175438596492
# Linear model: C = 0.05 score = 0.8256880733944955
# Linear model: C = 0.1 score = 0.8333333333333334
# Linear model: C = 0.5 score = 0.8333333333333334
# Linear model: C = 1 score = 0.8148148148148149
# Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# Time left 230.77900505065918
# Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.468624	valid's Opt metric: 0.688889
# [200]	valid's binary_logloss: 0.422113	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.408388	valid's Opt metric: 0.77551
# [400]	valid's binary_logloss: 0.40912	valid's Opt metric: 0.762887
# Early stopping, best iteration is:
# [250]	valid's binary_logloss: 0.412818	valid's Opt metric: 0.77551
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.473924	valid's Opt metric: 0.694737
# [200]	valid's binary_logloss: 0.42674	valid's Opt metric: 0.701031
# [300]	valid's binary_logloss: 0.411062	valid's Opt metric: 0.74
# [400]	valid's binary_logloss: 0.408399	valid's Opt metric: 0.764706
# [500]	valid's binary_logloss: 0.406048	valid's Opt metric: 0.757282
# [600]	valid's binary_logloss: 0.404512	valid's Opt metric: 0.769231
# [700]	valid's binary_logloss: 0.401329	valid's Opt metric: 0.757282
# Early stopping, best iteration is:
# [537]	valid's binary_logloss: 0.40482	valid's Opt metric: 0.769231
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.46077	valid's Opt metric: 0.77551
# [200]	valid's binary_logloss: 0.408926	valid's Opt metric: 0.776699
# [300]	valid's binary_logloss: 0.394026	valid's Opt metric: 0.761905
# Early stopping, best iteration is:
# [103]	valid's binary_logloss: 0.457719	valid's Opt metric: 0.787879
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.49304	valid's Opt metric: 0.6875
# [200]	valid's binary_logloss: 0.461472	valid's Opt metric: 0.718447
# [300]	valid's binary_logloss: 0.457412	valid's Opt metric: 0.72549
# Early stopping, best iteration is:
# [181]	valid's binary_logloss: 0.46426	valid's Opt metric: 0.732673
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.436706	valid's Opt metric: 0.804124
# [200]	valid's binary_logloss: 0.368916	valid's Opt metric: 0.838095
# [300]	valid's binary_logloss: 0.343696	valid's Opt metric: 0.836364
# [400]	valid's binary_logloss: 0.335899	valid's Opt metric: 0.828829
# Early stopping, best iteration is:
# [227]	valid's binary_logloss: 0.359237	valid's Opt metric: 0.851852
# Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Optuna may run 160.59967432022094 secs
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.457105	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.420678	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.412889	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.415049	valid's Opt metric: 0.76
# [500]	valid's binary_logloss: 0.428413	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [336]	valid's binary_logloss: 0.411273	valid's Opt metric: 0.755102
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.488304	valid's Opt metric: 0.666667
# [200]	valid's binary_logloss: 0.429544	valid's Opt metric: 0.717391
# [300]	valid's binary_logloss: 0.411774	valid's Opt metric: 0.757895
# [400]	valid's binary_logloss: 0.404875	valid's Opt metric: 0.762887
# [500]	valid's binary_logloss: 0.404798	valid's Opt metric: 0.762887
# Early stopping, best iteration is:
# [311]	valid's binary_logloss: 0.410864	valid's Opt metric: 0.770833
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466349	valid's Opt metric: 0.723404
# [200]	valid's binary_logloss: 0.418249	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.412369	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.413927	valid's Opt metric: 0.787879
# [500]	valid's binary_logloss: 0.420235	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [370]	valid's binary_logloss: 0.410465	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.461124	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.419505	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.413779	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.417196	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.430463	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [330]	valid's binary_logloss: 0.411555	valid's Opt metric: 0.767677
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465599	valid's Opt metric: 0.73913
# [200]	valid's binary_logloss: 0.420179	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.412154	valid's Opt metric: 0.75
# [400]	valid's binary_logloss: 0.416218	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.422165	valid's Opt metric: 0.767677
# Early stopping, best iteration is:
# [322]	valid's binary_logloss: 0.411057	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.494358	valid's Opt metric: 0.681818
# [200]	valid's binary_logloss: 0.449343	valid's Opt metric: 0.725275
# [300]	valid's binary_logloss: 0.433384	valid's Opt metric: 0.73913
# [400]	valid's binary_logloss: 0.425075	valid's Opt metric: 0.73913
# Early stopping, best iteration is:
# [290]	valid's binary_logloss: 0.43415	valid's Opt metric: 0.73913
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.46173	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.42425	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.414422	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.413625	valid's Opt metric: 0.76
# [500]	valid's binary_logloss: 0.42551	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [364]	valid's binary_logloss: 0.412687	valid's Opt metric: 0.767677
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.472062	valid's Opt metric: 0.711111
# [200]	valid's binary_logloss: 0.41924	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.408323	valid's Opt metric: 0.757895
# [400]	valid's binary_logloss: 0.408074	valid's Opt metric: 0.770833
# [500]	valid's binary_logloss: 0.414602	valid's Opt metric: 0.77551
# Early stopping, best iteration is:
# [326]	valid's binary_logloss: 0.406649	valid's Opt metric: 0.757895
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.471952	valid's Opt metric: 0.696629
# [200]	valid's binary_logloss: 0.423378	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.409864	valid's Opt metric: 0.736842
# [400]	valid's binary_logloss: 0.404708	valid's Opt metric: 0.736842
# Early stopping, best iteration is:
# [242]	valid's binary_logloss: 0.415882	valid's Opt metric: 0.736842
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.467566	valid's Opt metric: 0.711111
# [200]	valid's binary_logloss: 0.421305	valid's Opt metric: 0.762887
# [300]	valid's binary_logloss: 0.412806	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.416737	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.420544	valid's Opt metric: 0.767677
# Early stopping, best iteration is:
# [301]	valid's binary_logloss: 0.412878	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.46555	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.420424	valid's Opt metric: 0.762887
# [300]	valid's binary_logloss: 0.409716	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.411552	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.42104	valid's Opt metric: 0.792079
# Early stopping, best iteration is:
# [371]	valid's binary_logloss: 0.408171	valid's Opt metric: 0.783505
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464795	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.421297	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.413353	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.414189	valid's Opt metric: 0.767677
# [500]	valid's binary_logloss: 0.420422	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [381]	valid's binary_logloss: 0.412174	valid's Opt metric: 0.767677
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.469244	valid's Opt metric: 0.725275
# [200]	valid's binary_logloss: 0.423336	valid's Opt metric: 0.731183
# [300]	valid's binary_logloss: 0.414086	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.415928	valid's Opt metric: 0.762887
# Early stopping, best iteration is:
# [222]	valid's binary_logloss: 0.419189	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465023	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.420662	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.410365	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.414641	valid's Opt metric: 0.784314
# [500]	valid's binary_logloss: 0.42251	valid's Opt metric: 0.792079
# Early stopping, best iteration is:
# [348]	valid's binary_logloss: 0.409166	valid's Opt metric: 0.767677
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.463063	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.422365	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.415012	valid's Opt metric: 0.75
# Early stopping, best iteration is:
# [140]	valid's binary_logloss: 0.438203	valid's Opt metric: 0.75
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466986	valid's Opt metric: 0.723404
# [200]	valid's binary_logloss: 0.41939	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.411011	valid's Opt metric: 0.75
# [400]	valid's binary_logloss: 0.414926	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.420762	valid's Opt metric: 0.76
# Early stopping, best iteration is:
# [312]	valid's binary_logloss: 0.409659	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464961	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.420391	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.41216	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.412525	valid's Opt metric: 0.792079
# [500]	valid's binary_logloss: 0.418992	valid's Opt metric: 0.8
# [600]	valid's binary_logloss: 0.429463	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [413]	valid's binary_logloss: 0.411273	valid's Opt metric: 0.792079
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.462632	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.421159	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.414641	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.419284	valid's Opt metric: 0.767677
# [500]	valid's binary_logloss: 0.424559	valid's Opt metric: 0.784314
# Early stopping, best iteration is:
# [333]	valid's binary_logloss: 0.413341	valid's Opt metric: 0.755102
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465032	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.422935	valid's Opt metric: 0.709677
# [300]	valid's binary_logloss: 0.415491	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.416651	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.423063	valid's Opt metric: 0.792079
# Early stopping, best iteration is:
# [314]	valid's binary_logloss: 0.413841	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.462005	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.419707	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.41332	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.415888	valid's Opt metric: 0.767677
# [500]	valid's binary_logloss: 0.42421	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [321]	valid's binary_logloss: 0.412112	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466612	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.430969	valid's Opt metric: 0.709677
# [300]	valid's binary_logloss: 0.421234	valid's Opt metric: 0.736842
# [400]	valid's binary_logloss: 0.419377	valid's Opt metric: 0.75
# [500]	valid's binary_logloss: 0.420272	valid's Opt metric: 0.75
# Early stopping, best iteration is:
# [317]	valid's binary_logloss: 0.420492	valid's Opt metric: 0.75
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464079	valid's Opt metric: 0.681319
# [200]	valid's binary_logloss: 0.418606	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.410046	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.412609	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [296]	valid's binary_logloss: 0.409284	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.462604	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.422043	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.413146	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.416475	valid's Opt metric: 0.767677
# [500]	valid's binary_logloss: 0.424618	valid's Opt metric: 0.77551
# Early stopping, best iteration is:
# [308]	valid's binary_logloss: 0.412767	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.462979	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.419776	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.411731	valid's Opt metric: 0.77551
# [400]	valid's binary_logloss: 0.418387	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.423106	valid's Opt metric: 0.8
# Early stopping, best iteration is:
# [317]	valid's binary_logloss: 0.41068	valid's Opt metric: 0.767677
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465747	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.422964	valid's Opt metric: 0.709677
# [300]	valid's binary_logloss: 0.411377	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.41446	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [298]	valid's binary_logloss: 0.411178	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.461365	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.418982	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.413053	valid's Opt metric: 0.75
# [400]	valid's binary_logloss: 0.415145	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.42226	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [321]	valid's binary_logloss: 0.411215	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466658	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.423033	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.413998	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.415384	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.422771	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [371]	valid's binary_logloss: 0.412322	valid's Opt metric: 0.787879
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464949	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.421811	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.411422	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.412849	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.418257	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [378]	valid's binary_logloss: 0.409507	valid's Opt metric: 0.787879
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465737	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.423134	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.411611	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.413551	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.41985	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [371]	valid's binary_logloss: 0.409777	valid's Opt metric: 0.787879
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466963	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.418471	valid's Opt metric: 0.762887
# [300]	valid's binary_logloss: 0.409031	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.412079	valid's Opt metric: 0.762887
# Early stopping, best iteration is:
# [295]	valid's binary_logloss: 0.408629	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.46602	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.422	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.414595	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.414996	valid's Opt metric: 0.792079
# [500]	valid's binary_logloss: 0.421836	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [370]	valid's binary_logloss: 0.411768	valid's Opt metric: 0.767677
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.46804	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.423526	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.414606	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.41704	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.425058	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [351]	valid's binary_logloss: 0.413623	valid's Opt metric: 0.787879
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466676	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.423197	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.413344	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.417075	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.421215	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [305]	valid's binary_logloss: 0.412013	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465537	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.422991	valid's Opt metric: 0.709677
# [300]	valid's binary_logloss: 0.413209	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.416171	valid's Opt metric: 0.792079
# Early stopping, best iteration is:
# [295]	valid's binary_logloss: 0.412573	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466447	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.418845	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.409926	valid's Opt metric: 0.77551
# [400]	valid's binary_logloss: 0.409738	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.415406	valid's Opt metric: 0.772277
# Early stopping, best iteration is:
# [378]	valid's binary_logloss: 0.408303	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466023	valid's Opt metric: 0.731183
# [200]	valid's binary_logloss: 0.420751	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.412972	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.413492	valid's Opt metric: 0.77551
# Early stopping, best iteration is:
# [276]	valid's binary_logloss: 0.411461	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.467092	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.422563	valid's Opt metric: 0.709677
# [300]	valid's binary_logloss: 0.411552	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.411165	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.417438	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [384]	valid's binary_logloss: 0.408856	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464457	valid's Opt metric: 0.723404
# [200]	valid's binary_logloss: 0.418156	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.409816	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.412846	valid's Opt metric: 0.77551
# Early stopping, best iteration is:
# [245]	valid's binary_logloss: 0.411676	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464922	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.420617	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.410004	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.411562	valid's Opt metric: 0.792079
# [500]	valid's binary_logloss: 0.418327	valid's Opt metric: 0.8
# Early stopping, best iteration is:
# [370]	valid's binary_logloss: 0.40762	valid's Opt metric: 0.767677
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466441	valid's Opt metric: 0.725275
# [200]	valid's binary_logloss: 0.42245	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.412123	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.416122	valid's Opt metric: 0.762887
# Early stopping, best iteration is:
# [258]	valid's binary_logloss: 0.413359	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.4653	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.422344	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.413487	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.413795	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [295]	valid's binary_logloss: 0.412682	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465013	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.421378	valid's Opt metric: 0.709677
# [300]	valid's binary_logloss: 0.413165	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.410788	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.418191	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [350]	valid's binary_logloss: 0.411462	valid's Opt metric: 0.787879
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465605	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.418033	valid's Opt metric: 0.762887
# [300]	valid's binary_logloss: 0.408007	valid's Opt metric: 0.77551
# [400]	valid's binary_logloss: 0.409688	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [271]	valid's binary_logloss: 0.41003	valid's Opt metric: 0.787879
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.467009	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.420878	valid's Opt metric: 0.762887
# [300]	valid's binary_logloss: 0.411013	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.411767	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.418929	valid's Opt metric: 0.772277
# Early stopping, best iteration is:
# [371]	valid's binary_logloss: 0.409414	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.467678	valid's Opt metric: 0.731183
# [200]	valid's binary_logloss: 0.421339	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.40954	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.411699	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.420774	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [329]	valid's binary_logloss: 0.407239	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.463473	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.419977	valid's Opt metric: 0.709677
# [300]	valid's binary_logloss: 0.409214	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.415369	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.422303	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [302]	valid's binary_logloss: 0.408757	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.46562	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.419776	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.409358	valid's Opt metric: 0.75
# [400]	valid's binary_logloss: 0.409378	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.414629	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [378]	valid's binary_logloss: 0.407037	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.500146	valid's Opt metric: 0.681818
# [200]	valid's binary_logloss: 0.446157	valid's Opt metric: 0.73913
# [300]	valid's binary_logloss: 0.424556	valid's Opt metric: 0.73913
# [400]	valid's binary_logloss: 0.413966	valid's Opt metric: 0.736842
# [500]	valid's binary_logloss: 0.408329	valid's Opt metric: 0.77551
# [600]	valid's binary_logloss: 0.405026	valid's Opt metric: 0.77551
# Early stopping, best iteration is:
# [499]	valid's binary_logloss: 0.408416	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.4683	valid's Opt metric: 0.717391
# [200]	valid's binary_logloss: 0.418652	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.41044	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.410689	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.416467	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [387]	valid's binary_logloss: 0.40864	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.467485	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.423243	valid's Opt metric: 0.709677
# [300]	valid's binary_logloss: 0.414481	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.415095	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.423421	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [326]	valid's binary_logloss: 0.411913	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465088	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.420521	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.410835	valid's Opt metric: 0.77551
# [400]	valid's binary_logloss: 0.413701	valid's Opt metric: 0.767677
# [500]	valid's binary_logloss: 0.419683	valid's Opt metric: 0.8
# Early stopping, best iteration is:
# [331]	valid's binary_logloss: 0.409468	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465771	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.425067	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.413814	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.415133	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [294]	valid's binary_logloss: 0.413092	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466972	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.421167	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.414904	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.417592	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [294]	valid's binary_logloss: 0.413944	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464769	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.417998	valid's Opt metric: 0.762887
# [300]	valid's binary_logloss: 0.407842	valid's Opt metric: 0.77551
# [400]	valid's binary_logloss: 0.411921	valid's Opt metric: 0.77551
# Early stopping, best iteration is:
# [252]	valid's binary_logloss: 0.410379	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464731	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.422409	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.413033	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.413555	valid's Opt metric: 0.772277
# Early stopping, best iteration is:
# [263]	valid's binary_logloss: 0.41147	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.46514	valid's Opt metric: 0.703297
# [200]	valid's binary_logloss: 0.422137	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.411768	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.410007	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.415016	valid's Opt metric: 0.77551
# Early stopping, best iteration is:
# [371]	valid's binary_logloss: 0.408072	valid's Opt metric: 0.755102
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466428	valid's Opt metric: 0.725275
# [200]	valid's binary_logloss: 0.41884	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.412015	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.413415	valid's Opt metric: 0.762887
# Early stopping, best iteration is:
# [215]	valid's binary_logloss: 0.416504	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466158	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.4228	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.413259	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.412621	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.417896	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [370]	valid's binary_logloss: 0.410293	valid's Opt metric: 0.767677
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.46135	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.420406	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.413321	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.415361	valid's Opt metric: 0.767677
# [500]	valid's binary_logloss: 0.426503	valid's Opt metric: 0.8
# Early stopping, best iteration is:
# [322]	valid's binary_logloss: 0.412509	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464292	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.420585	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.411312	valid's Opt metric: 0.75
# [400]	valid's binary_logloss: 0.41427	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.417889	valid's Opt metric: 0.767677
# Early stopping, best iteration is:
# [324]	valid's binary_logloss: 0.410117	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464018	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.421814	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.413815	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.417523	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.42351	valid's Opt metric: 0.8
# Early stopping, best iteration is:
# [333]	valid's binary_logloss: 0.412782	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465174	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.42101	valid's Opt metric: 0.709677
# [300]	valid's binary_logloss: 0.411271	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.413333	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.420691	valid's Opt metric: 0.792079
# Early stopping, best iteration is:
# [370]	valid's binary_logloss: 0.409024	valid's Opt metric: 0.78
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464414	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.422097	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.412348	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.413024	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.420707	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [378]	valid's binary_logloss: 0.410067	valid's Opt metric: 0.78
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464357	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.418919	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.407692	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.40891	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.416688	valid's Opt metric: 0.8
# Early stopping, best iteration is:
# [364]	valid's binary_logloss: 0.405057	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.46898	valid's Opt metric: 0.703297
# [200]	valid's binary_logloss: 0.421423	valid's Opt metric: 0.731183
# [300]	valid's binary_logloss: 0.413051	valid's Opt metric: 0.757895
# [400]	valid's binary_logloss: 0.414689	valid's Opt metric: 0.770833
# [500]	valid's binary_logloss: 0.420683	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [325]	valid's binary_logloss: 0.411728	valid's Opt metric: 0.770833
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.469256	valid's Opt metric: 0.688889
# [200]	valid's binary_logloss: 0.421481	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.413313	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.41615	valid's Opt metric: 0.762887
# [500]	valid's binary_logloss: 0.420325	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [309]	valid's binary_logloss: 0.41217	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466651	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.423998	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.415691	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.414395	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.421084	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [368]	valid's binary_logloss: 0.413199	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.471147	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.423042	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.411497	valid's Opt metric: 0.77551
# [400]	valid's binary_logloss: 0.409966	valid's Opt metric: 0.762887
# Early stopping, best iteration is:
# [242]	valid's binary_logloss: 0.416581	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.461347	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.421065	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.412165	valid's Opt metric: 0.77551
# [400]	valid's binary_logloss: 0.415933	valid's Opt metric: 0.772277
# [500]	valid's binary_logloss: 0.424232	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [320]	valid's binary_logloss: 0.41169	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465421	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.419	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.407757	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.408858	valid's Opt metric: 0.77551
# Early stopping, best iteration is:
# [297]	valid's binary_logloss: 0.40717	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465919	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.419993	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.409963	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.410758	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.417878	valid's Opt metric: 0.772277
# Early stopping, best iteration is:
# [370]	valid's binary_logloss: 0.407872	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465719	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.420542	valid's Opt metric: 0.762887
# [300]	valid's binary_logloss: 0.409596	valid's Opt metric: 0.787879
# [400]	valid's binary_logloss: 0.413626	valid's Opt metric: 0.767677
# [500]	valid's binary_logloss: 0.421998	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [371]	valid's binary_logloss: 0.408592	valid's Opt metric: 0.767677
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465788	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.422707	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.413721	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.417267	valid's Opt metric: 0.792079
# [500]	valid's binary_logloss: 0.423248	valid's Opt metric: 0.792079
# Early stopping, best iteration is:
# [326]	valid's binary_logloss: 0.412234	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464696	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.42187	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.413254	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.413598	valid's Opt metric: 0.767677
# [500]	valid's binary_logloss: 0.421374	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [371]	valid's binary_logloss: 0.411449	valid's Opt metric: 0.767677
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464105	valid's Opt metric: 0.695652
# [200]	valid's binary_logloss: 0.418876	valid's Opt metric: 0.736842
# [300]	valid's binary_logloss: 0.410582	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.414138	valid's Opt metric: 0.767677
# Early stopping, best iteration is:
# [244]	valid's binary_logloss: 0.412832	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466242	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.423886	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.411971	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.41356	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.420453	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [377]	valid's binary_logloss: 0.410285	valid's Opt metric: 0.787879
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.468165	valid's Opt metric: 0.681319
# [200]	valid's binary_logloss: 0.422905	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.411067	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.409321	valid's Opt metric: 0.762887
# Early stopping, best iteration is:
# [265]	valid's binary_logloss: 0.412235	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.499419	valid's Opt metric: 0.696629
# [200]	valid's binary_logloss: 0.45381	valid's Opt metric: 0.725275
# [300]	valid's binary_logloss: 0.436642	valid's Opt metric: 0.731183
# [400]	valid's binary_logloss: 0.428508	valid's Opt metric: 0.731183
# Early stopping, best iteration is:
# [216]	valid's binary_logloss: 0.450127	valid's Opt metric: 0.73913
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.465083	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.423267	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.414095	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.415229	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.422441	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [348]	valid's binary_logloss: 0.414066	valid's Opt metric: 0.787879
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466364	valid's Opt metric: 0.717391
# [200]	valid's binary_logloss: 0.421386	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.411641	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.412028	valid's Opt metric: 0.77551
# [500]	valid's binary_logloss: 0.41776	valid's Opt metric: 0.78
# [600]	valid's binary_logloss: 0.425883	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [402]	valid's binary_logloss: 0.411436	valid's Opt metric: 0.787879
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.467981	valid's Opt metric: 0.709677
# [200]	valid's binary_logloss: 0.423052	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.412733	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.414436	valid's Opt metric: 0.767677
# [500]	valid's binary_logloss: 0.418203	valid's Opt metric: 0.772277
# Early stopping, best iteration is:
# [327]	valid's binary_logloss: 0.412153	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.466966	valid's Opt metric: 0.703297
# [200]	valid's binary_logloss: 0.421927	valid's Opt metric: 0.75
# [300]	valid's binary_logloss: 0.411391	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.410835	valid's Opt metric: 0.767677
# [500]	valid's binary_logloss: 0.417252	valid's Opt metric: 0.787879
# [600]	valid's binary_logloss: 0.423439	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [412]	valid's binary_logloss: 0.409776	valid's Opt metric: 0.767677
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.468974	valid's Opt metric: 0.717391
# [200]	valid's binary_logloss: 0.422685	valid's Opt metric: 0.723404
# [300]	valid's binary_logloss: 0.41335	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.410686	valid's Opt metric: 0.78
# [500]	valid's binary_logloss: 0.41362	valid's Opt metric: 0.78
# Early stopping, best iteration is:
# [364]	valid's binary_logloss: 0.408697	valid's Opt metric: 0.77551
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.469172	valid's Opt metric: 0.725275
# [200]	valid's binary_logloss: 0.423196	valid's Opt metric: 0.757895
# [300]	valid's binary_logloss: 0.412633	valid's Opt metric: 0.762887
# [400]	valid's binary_logloss: 0.417007	valid's Opt metric: 0.762887
# [500]	valid's binary_logloss: 0.421507	valid's Opt metric: 0.787879
# Early stopping, best iteration is:
# [322]	valid's binary_logloss: 0.411945	valid's Opt metric: 0.762887
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.42083	valid's Opt metric: 0.76
# Early stopping, best iteration is:
# [66]	valid's binary_logloss: 0.406897	valid's Opt metric: 0.77551
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.398308	valid's Opt metric: 0.75
# Early stopping, best iteration is:
# [72]	valid's binary_logloss: 0.399406	valid's Opt metric: 0.785047
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.407747	valid's Opt metric: 0.789474
# Early stopping, best iteration is:
# [60]	valid's binary_logloss: 0.40154	valid's Opt metric: 0.814159
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.480074	valid's Opt metric: 0.730769
# Early stopping, best iteration is:
# [50]	valid's binary_logloss: 0.444981	valid's Opt metric: 0.737864
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.337548	valid's Opt metric: 0.834783
# Early stopping, best iteration is:
# [38]	valid's binary_logloss: 0.358285	valid's Opt metric: 0.867925
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Time left 58.781007528305054
# Blending: Optimization starts with equal weights and score 0.7683397683397682
# Blending, iter 0: score = 0.7840909090909092, weights = [0.15324706 0.         0.84675294]
# Blending, iter 1: score = 0.7840909090909092, weights = [0.15324706 0.         0.84675294]
# No score update. Terminated
#
# Automl preset training completed in 191.35 seconds.

# %%
valid_pred = df_valid.copy()

valid_pred = tautoml.predict(df_valid)

print(f"OOF acc: {acc_score(df_train['Survived'].values, oof_pred.data[:, 0])}")
print(f"VAL acc: {acc_score(df_valid['Survived'].values, valid_pred.data[:, 0])}")
# Out:
# OOF acc: 0.8398876404494382
# VAL acc: 0.7988826815642458

# %% [markdown]
# ## Retrain selected model on the full dataset and predict for the real test

# %%
tautoml = TabularUtilizedAutoML(task = task, 
                                timeout = 600, # 600 seconds = 10 minutes
                                memory_limit = 6, # Optimal run for your pc
                                cpu_limit = 4, # Optimal CPU for your pc
                                general_params = {'use_algos': [['linear_l2', 
                                                  'lgb', 'lgb_tuned']]})

oof_pred = tautoml.fit_predict(data, roles = roles)

test_pred = tautoml.predict(test)
# Out:
# Current random state: {'reader_params': {'random_state': 42}, 'general_params': {'return_all_predictions': False}}
# Found general_params in kwargs, need to combine
# Merged variant for general_params = {'use_algos': [['linear_l2', 'lgb', 'lgb_tuned']], 'return_all_predictions': False}
# Start automl preset with listed constraints:
# - time: 599.9920039176941 seconds
# - cpus: 4 cores
# - memory: 6 gb
#
# Train data shape: (891, 12)
# Feats was rejected during automatic roles guess: []
#
#
# Layer 1 ...
# Train process start. Time left 599.114007472992 secs
# Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = 0.0
# Linear model: C = 5e-05 score = 0.0
# Linear model: C = 0.0001 score = 0.13513513513513511
# Linear model: C = 0.0005 score = 0.7286821705426356
# Linear model: C = 0.001 score = 0.7480916030534351
# Linear model: C = 0.005 score = 0.7480916030534351
# Linear model: C = 0.01 score = 0.732824427480916
#
# ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = 0.0
# Linear model: C = 5e-05 score = 0.0
# Linear model: C = 0.0001 score = 0.18666666666666665
# Linear model: C = 0.0005 score = 0.688
# Linear model: C = 0.001 score = 0.6929133858267716
# Linear model: C = 0.005 score = 0.7031250000000001
# Linear model: C = 0.01 score = 0.7328244274809159
# Linear model: C = 0.05 score = 0.7313432835820897
# Linear model: C = 0.1 score = 0.75
# Linear model: C = 0.5 score = 0.75
# Linear model: C = 1 score = 0.7445255474452556
#
# ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = 0.0
# Linear model: C = 5e-05 score = 0.0
# Linear model: C = 0.0001 score = 0.21052631578947367
# Linear model: C = 0.0005 score = 0.6949152542372881
# Linear model: C = 0.001 score = 0.7166666666666666
# Linear model: C = 0.005 score = 0.6935483870967742
# Linear model: C = 0.01 score = 0.7142857142857142
#
# ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = 0.0
# Linear model: C = 5e-05 score = 0.0
# Linear model: C = 0.0001 score = 0.18666666666666665
# Linear model: C = 0.0005 score = 0.7479674796747968
# Linear model: C = 0.001 score = 0.7401574803149606
# Linear model: C = 0.005 score = 0.7656250000000001
# Linear model: C = 0.01 score = 0.7727272727272727
# Linear model: C = 0.05 score = 0.7611940298507464
# Linear model: C = 0.1 score = 0.7611940298507464
#
# ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = 0.0
# Linear model: C = 5e-05 score = 0.0
# Linear model: C = 0.0001 score = 0.20779220779220778
# Linear model: C = 0.0005 score = 0.761904761904762
# Linear model: C = 0.001 score = 0.7938931297709925
# Linear model: C = 0.005 score = 0.8059701492537313
# Linear model: C = 0.01 score = 0.8115942028985508
# Linear model: C = 0.05 score = 0.8148148148148148
# Linear model: C = 0.1 score = 0.8088235294117647
# Linear model: C = 0.5 score = 0.8088235294117647
# Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# Time left 596.478004693985
# Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.469267	valid's Opt metric: 0.722689
# [200]	valid's binary_logloss: 0.404896	valid's Opt metric: 0.752
# [300]	valid's binary_logloss: 0.379535	valid's Opt metric: 0.761905
# [400]	valid's binary_logloss: 0.367073	valid's Opt metric: 0.761905
# [500]	valid's binary_logloss: 0.360941	valid's Opt metric: 0.768
# [600]	valid's binary_logloss: 0.356018	valid's Opt metric: 0.768
# [700]	valid's binary_logloss: 0.351948	valid's Opt metric: 0.777778
# [800]	valid's binary_logloss: 0.35002	valid's Opt metric: 0.777778
# Early stopping, best iteration is:
# [650]	valid's binary_logloss: 0.355132	valid's Opt metric: 0.777778
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.487409	valid's Opt metric: 0.666667
# [200]	valid's binary_logloss: 0.435351	valid's Opt metric: 0.725806
# [300]	valid's binary_logloss: 0.419574	valid's Opt metric: 0.763359
# [400]	valid's binary_logloss: 0.415093	valid's Opt metric: 0.757576
# Early stopping, best iteration is:
# [256]	valid's binary_logloss: 0.423982	valid's Opt metric: 0.769231
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.498965	valid's Opt metric: 0.654545
# [200]	valid's binary_logloss: 0.451438	valid's Opt metric: 0.722689
# [300]	valid's binary_logloss: 0.433964	valid's Opt metric: 0.721311
# Early stopping, best iteration is:
# [177]	valid's binary_logloss: 0.458522	valid's Opt metric: 0.728814
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.497425	valid's Opt metric: 0.786885
# [200]	valid's binary_logloss: 0.439963	valid's Opt metric: 0.787879
# [300]	valid's binary_logloss: 0.414837	valid's Opt metric: 0.781955
# Early stopping, best iteration is:
# [103]	valid's binary_logloss: 0.49515	valid's Opt metric: 0.806452
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.469808	valid's Opt metric: 0.733333
# [200]	valid's binary_logloss: 0.407567	valid's Opt metric: 0.796875
# [300]	valid's binary_logloss: 0.386802	valid's Opt metric: 0.78125
# Early stopping, best iteration is:
# [179]	valid's binary_logloss: 0.416786	valid's Opt metric: 0.796875
# Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# Optuna may run 481.6517869949341 secs
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.447664	valid's Opt metric: 0.739496
# [200]	valid's binary_logloss: 0.375763	valid's Opt metric: 0.752
# [300]	valid's binary_logloss: 0.35074	valid's Opt metric: 0.768
# [400]	valid's binary_logloss: 0.343276	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.337373	valid's Opt metric: 0.793651
# Early stopping, best iteration is:
# [385]	valid's binary_logloss: 0.342368	valid's Opt metric: 0.793651
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.49944	valid's Opt metric: 0.717949
# [200]	valid's binary_logloss: 0.436061	valid's Opt metric: 0.741935
# [300]	valid's binary_logloss: 0.405554	valid's Opt metric: 0.761905
# [400]	valid's binary_logloss: 0.38711	valid's Opt metric: 0.761905
# Early stopping, best iteration is:
# [296]	valid's binary_logloss: 0.406395	valid's Opt metric: 0.761905
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.449503	valid's Opt metric: 0.716667
# [200]	valid's binary_logloss: 0.39101	valid's Opt metric: 0.741935
# [300]	valid's binary_logloss: 0.36481	valid's Opt metric: 0.761905
# [400]	valid's binary_logloss: 0.355949	valid's Opt metric: 0.768
# [500]	valid's binary_logloss: 0.350026	valid's Opt metric: 0.777778
# [600]	valid's binary_logloss: 0.34807	valid's Opt metric: 0.777778
# [700]	valid's binary_logloss: 0.347009	valid's Opt metric: 0.787402
# [800]	valid's binary_logloss: 0.348683	valid's Opt metric: 0.784
# [900]	valid's binary_logloss: 0.350712	valid's Opt metric: 0.784
# Early stopping, best iteration is:
# [721]	valid's binary_logloss: 0.346746	valid's Opt metric: 0.793651
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.446731	valid's Opt metric: 0.733333
# [200]	valid's binary_logloss: 0.376882	valid's Opt metric: 0.752
# [300]	valid's binary_logloss: 0.350854	valid's Opt metric: 0.752
# [400]	valid's binary_logloss: 0.342279	valid's Opt metric: 0.784
# [500]	valid's binary_logloss: 0.337706	valid's Opt metric: 0.774194
# [600]	valid's binary_logloss: 0.339547	valid's Opt metric: 0.774194
# [700]	valid's binary_logloss: 0.339807	valid's Opt metric: 0.784
# Early stopping, best iteration is:
# [506]	valid's binary_logloss: 0.337773	valid's Opt metric: 0.793651
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.455397	valid's Opt metric: 0.705882
# [200]	valid's binary_logloss: 0.390933	valid's Opt metric: 0.752
# [300]	valid's binary_logloss: 0.365628	valid's Opt metric: 0.761905
# [400]	valid's binary_logloss: 0.354646	valid's Opt metric: 0.761905
# Early stopping, best iteration is:
# [205]	valid's binary_logloss: 0.389064	valid's Opt metric: 0.761905
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.495778	valid's Opt metric: 0.706897
# [200]	valid's binary_logloss: 0.445177	valid's Opt metric: 0.717949
# [300]	valid's binary_logloss: 0.426656	valid's Opt metric: 0.716667
# Early stopping, best iteration is:
# [114]	valid's binary_logloss: 0.484951	valid's Opt metric: 0.717949
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.449934	valid's Opt metric: 0.728814
# [200]	valid's binary_logloss: 0.378704	valid's Opt metric: 0.741935
# [300]	valid's binary_logloss: 0.351629	valid's Opt metric: 0.758065
# [400]	valid's binary_logloss: 0.341096	valid's Opt metric: 0.784
# [500]	valid's binary_logloss: 0.335283	valid's Opt metric: 0.793651
# [600]	valid's binary_logloss: 0.335589	valid's Opt metric: 0.784
# Early stopping, best iteration is:
# [450]	valid's binary_logloss: 0.337947	valid's Opt metric: 0.793651
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.470353	valid's Opt metric: 0.75
# [200]	valid's binary_logloss: 0.403913	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.370884	valid's Opt metric: 0.752
# Early stopping, best iteration is:
# [129]	valid's binary_logloss: 0.446171	valid's Opt metric: 0.770492
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.473034	valid's Opt metric: 0.705882
# [200]	valid's binary_logloss: 0.41337	valid's Opt metric: 0.741935
# [300]	valid's binary_logloss: 0.390281	valid's Opt metric: 0.741935
# [400]	valid's binary_logloss: 0.379853	valid's Opt metric: 0.752
# [500]	valid's binary_logloss: 0.372482	valid's Opt metric: 0.752
# Early stopping, best iteration is:
# [313]	valid's binary_logloss: 0.388437	valid's Opt metric: 0.752
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.456246	valid's Opt metric: 0.710744
# [200]	valid's binary_logloss: 0.397124	valid's Opt metric: 0.741935
# [300]	valid's binary_logloss: 0.372317	valid's Opt metric: 0.752
# [400]	valid's binary_logloss: 0.363907	valid's Opt metric: 0.761905
# [500]	valid's binary_logloss: 0.359479	valid's Opt metric: 0.768
# [600]	valid's binary_logloss: 0.355907	valid's Opt metric: 0.768
# Early stopping, best iteration is:
# [435]	valid's binary_logloss: 0.362288	valid's Opt metric: 0.768
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.445137	valid's Opt metric: 0.739496
# [200]	valid's binary_logloss: 0.374858	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.348289	valid's Opt metric: 0.774194
# [400]	valid's binary_logloss: 0.339544	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.335137	valid's Opt metric: 0.793651
# [600]	valid's binary_logloss: 0.333177	valid's Opt metric: 0.793651
# Early stopping, best iteration is:
# [435]	valid's binary_logloss: 0.336206	valid's Opt metric: 0.80315
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.445221	valid's Opt metric: 0.75
# [200]	valid's binary_logloss: 0.373418	valid's Opt metric: 0.764228
# [300]	valid's binary_logloss: 0.347852	valid's Opt metric: 0.790323
# [400]	valid's binary_logloss: 0.337852	valid's Opt metric: 0.8
# [500]	valid's binary_logloss: 0.336044	valid's Opt metric: 0.784
# Early stopping, best iteration is:
# [309]	valid's binary_logloss: 0.346841	valid's Opt metric: 0.8
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.45331	valid's Opt metric: 0.739496
# [200]	valid's binary_logloss: 0.375989	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.346611	valid's Opt metric: 0.758065
# [400]	valid's binary_logloss: 0.335523	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.333982	valid's Opt metric: 0.8125
# [600]	valid's binary_logloss: 0.332297	valid's Opt metric: 0.821705
# [700]	valid's binary_logloss: 0.33462	valid's Opt metric: 0.830769
# Early stopping, best iteration is:
# [581]	valid's binary_logloss: 0.331346	valid's Opt metric: 0.8125
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.453237	valid's Opt metric: 0.728814
# [200]	valid's binary_logloss: 0.378948	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.349578	valid's Opt metric: 0.752
# Early stopping, best iteration is:
# [118]	valid's binary_logloss: 0.435512	valid's Opt metric: 0.770492
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.454254	valid's Opt metric: 0.739496
# [200]	valid's binary_logloss: 0.380169	valid's Opt metric: 0.747967
# [300]	valid's binary_logloss: 0.349061	valid's Opt metric: 0.758065
# [400]	valid's binary_logloss: 0.336826	valid's Opt metric: 0.784
# [500]	valid's binary_logloss: 0.333002	valid's Opt metric: 0.784
# [600]	valid's binary_logloss: 0.331804	valid's Opt metric: 0.793651
# [700]	valid's binary_logloss: 0.331105	valid's Opt metric: 0.80315
# [800]	valid's binary_logloss: 0.332664	valid's Opt metric: 0.80315
# Early stopping, best iteration is:
# [697]	valid's binary_logloss: 0.3315	valid's Opt metric: 0.8125
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.46488	valid's Opt metric: 0.728814
# [200]	valid's binary_logloss: 0.394266	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.363842	valid's Opt metric: 0.752
# Early stopping, best iteration is:
# [133]	valid's binary_logloss: 0.436013	valid's Opt metric: 0.770492
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.441841	valid's Opt metric: 0.727273
# [200]	valid's binary_logloss: 0.383247	valid's Opt metric: 0.752
# [300]	valid's binary_logloss: 0.361941	valid's Opt metric: 0.752
# [400]	valid's binary_logloss: 0.350957	valid's Opt metric: 0.774194
# [500]	valid's binary_logloss: 0.345778	valid's Opt metric: 0.774194
# [600]	valid's binary_logloss: 0.34394	valid's Opt metric: 0.784
# [700]	valid's binary_logloss: 0.346422	valid's Opt metric: 0.784
# Early stopping, best iteration is:
# [584]	valid's binary_logloss: 0.343542	valid's Opt metric: 0.793651
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.467256	valid's Opt metric: 0.728814
# [200]	valid's binary_logloss: 0.396698	valid's Opt metric: 0.764228
# [300]	valid's binary_logloss: 0.364209	valid's Opt metric: 0.764228
# Early stopping, best iteration is:
# [135]	valid's binary_logloss: 0.435896	valid's Opt metric: 0.770492
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.44483	valid's Opt metric: 0.722689
# [200]	valid's binary_logloss: 0.372752	valid's Opt metric: 0.752
# [300]	valid's binary_logloss: 0.346541	valid's Opt metric: 0.752
# [400]	valid's binary_logloss: 0.33737	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.329871	valid's Opt metric: 0.793651
# [600]	valid's binary_logloss: 0.327774	valid's Opt metric: 0.793651
# [700]	valid's binary_logloss: 0.329814	valid's Opt metric: 0.793651
# Early stopping, best iteration is:
# [543]	valid's binary_logloss: 0.327764	valid's Opt metric: 0.80315
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.44462	valid's Opt metric: 0.727273
# [200]	valid's binary_logloss: 0.388829	valid's Opt metric: 0.754098
# [300]	valid's binary_logloss: 0.370331	valid's Opt metric: 0.758065
# [400]	valid's binary_logloss: 0.357869	valid's Opt metric: 0.761905
# [500]	valid's binary_logloss: 0.350892	valid's Opt metric: 0.780488
# [600]	valid's binary_logloss: 0.345849	valid's Opt metric: 0.780488
# [700]	valid's binary_logloss: 0.344135	valid's Opt metric: 0.8
# [800]	valid's binary_logloss: 0.345063	valid's Opt metric: 0.8
# Early stopping, best iteration is:
# [641]	valid's binary_logloss: 0.345581	valid's Opt metric: 0.8
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.452801	valid's Opt metric: 0.728814
# [200]	valid's binary_logloss: 0.377091	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.347332	valid's Opt metric: 0.758065
# [400]	valid's binary_logloss: 0.338362	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.336407	valid's Opt metric: 0.80315
# [600]	valid's binary_logloss: 0.335864	valid's Opt metric: 0.821705
# [700]	valid's binary_logloss: 0.336858	valid's Opt metric: 0.830769
# Early stopping, best iteration is:
# [584]	valid's binary_logloss: 0.334902	valid's Opt metric: 0.821705
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.450624	valid's Opt metric: 0.728814
# [200]	valid's binary_logloss: 0.378401	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.349305	valid's Opt metric: 0.758065
# Early stopping, best iteration is:
# [120]	valid's binary_logloss: 0.430165	valid's Opt metric: 0.770492
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.445126	valid's Opt metric: 0.739496
# [200]	valid's binary_logloss: 0.372403	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.346871	valid's Opt metric: 0.764228
# [400]	valid's binary_logloss: 0.337383	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.335605	valid's Opt metric: 0.80315
# [600]	valid's binary_logloss: 0.331824	valid's Opt metric: 0.821705
# [700]	valid's binary_logloss: 0.333706	valid's Opt metric: 0.821705
# Early stopping, best iteration is:
# [578]	valid's binary_logloss: 0.331896	valid's Opt metric: 0.821705
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.445739	valid's Opt metric: 0.739496
# [200]	valid's binary_logloss: 0.372346	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.34848	valid's Opt metric: 0.764228
# [400]	valid's binary_logloss: 0.337679	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.334124	valid's Opt metric: 0.821705
# [600]	valid's binary_logloss: 0.331131	valid's Opt metric: 0.8125
# [700]	valid's binary_logloss: 0.332103	valid's Opt metric: 0.821705
# Early stopping, best iteration is:
# [501]	valid's binary_logloss: 0.334074	valid's Opt metric: 0.830769
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.445028	valid's Opt metric: 0.722689
# [200]	valid's binary_logloss: 0.373172	valid's Opt metric: 0.752
# [300]	valid's binary_logloss: 0.348253	valid's Opt metric: 0.761905
# [400]	valid's binary_logloss: 0.338074	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.331263	valid's Opt metric: 0.793651
# Early stopping, best iteration is:
# [369]	valid's binary_logloss: 0.33891	valid's Opt metric: 0.793651
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.458436	valid's Opt metric: 0.739496
# [200]	valid's binary_logloss: 0.38337	valid's Opt metric: 0.764228
# [300]	valid's binary_logloss: 0.35118	valid's Opt metric: 0.758065
# Early stopping, best iteration is:
# [128]	valid's binary_logloss: 0.431072	valid's Opt metric: 0.770492
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.448341	valid's Opt metric: 0.728814
# [200]	valid's binary_logloss: 0.379597	valid's Opt metric: 0.741935
# [300]	valid's binary_logloss: 0.355483	valid's Opt metric: 0.752
# Early stopping, best iteration is:
# [131]	valid's binary_logloss: 0.421963	valid's Opt metric: 0.754098
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.44539	valid's Opt metric: 0.739496
# [200]	valid's binary_logloss: 0.373879	valid's Opt metric: 0.747967
# [300]	valid's binary_logloss: 0.349047	valid's Opt metric: 0.754098
# [400]	valid's binary_logloss: 0.339706	valid's Opt metric: 0.784
# [500]	valid's binary_logloss: 0.337821	valid's Opt metric: 0.80315
# [600]	valid's binary_logloss: 0.338508	valid's Opt metric: 0.821705
# [700]	valid's binary_logloss: 0.339816	valid's Opt metric: 0.821705
# Early stopping, best iteration is:
# [536]	valid's binary_logloss: 0.33619	valid's Opt metric: 0.8125
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.450267	valid's Opt metric: 0.716667
# [200]	valid's binary_logloss: 0.381577	valid's Opt metric: 0.752
# [300]	valid's binary_logloss: 0.356449	valid's Opt metric: 0.758065
# Early stopping, best iteration is:
# [137]	valid's binary_logloss: 0.41662	valid's Opt metric: 0.758065
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.444773	valid's Opt metric: 0.722689
# [200]	valid's binary_logloss: 0.37277	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.348261	valid's Opt metric: 0.774194
# [400]	valid's binary_logloss: 0.338996	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.333189	valid's Opt metric: 0.793651
# Early stopping, best iteration is:
# [382]	valid's binary_logloss: 0.339513	valid's Opt metric: 0.793651
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.452699	valid's Opt metric: 0.739496
# [200]	valid's binary_logloss: 0.376369	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.34815	valid's Opt metric: 0.758065
# Early stopping, best iteration is:
# [113]	valid's binary_logloss: 0.439033	valid's Opt metric: 0.770492
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.445738	valid's Opt metric: 0.739496
# [200]	valid's binary_logloss: 0.372346	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.34848	valid's Opt metric: 0.764228
# [400]	valid's binary_logloss: 0.33768	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.333982	valid's Opt metric: 0.821705
# [600]	valid's binary_logloss: 0.331885	valid's Opt metric: 0.8125
# Early stopping, best iteration is:
# [497]	valid's binary_logloss: 0.334222	valid's Opt metric: 0.821705
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.444572	valid's Opt metric: 0.728814
# [200]	valid's binary_logloss: 0.373418	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.34725	valid's Opt metric: 0.777778
# [400]	valid's binary_logloss: 0.336494	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.332362	valid's Opt metric: 0.793651
# [600]	valid's binary_logloss: 0.331902	valid's Opt metric: 0.8125
# [700]	valid's binary_logloss: 0.33221	valid's Opt metric: 0.80315
# Early stopping, best iteration is:
# [548]	valid's binary_logloss: 0.330685	valid's Opt metric: 0.80315
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.443022	valid's Opt metric: 0.739496
# [200]	valid's binary_logloss: 0.373046	valid's Opt metric: 0.747967
# [300]	valid's binary_logloss: 0.349892	valid's Opt metric: 0.768
# [400]	valid's binary_logloss: 0.342048	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.335641	valid's Opt metric: 0.784
# [600]	valid's binary_logloss: 0.333997	valid's Opt metric: 0.793651
# [700]	valid's binary_logloss: 0.33442	valid's Opt metric: 0.793651
# Early stopping, best iteration is:
# [548]	valid's binary_logloss: 0.332577	valid's Opt metric: 0.80315
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.463005	valid's Opt metric: 0.739496
# [200]	valid's binary_logloss: 0.390219	valid's Opt metric: 0.764228
# [300]	valid's binary_logloss: 0.358527	valid's Opt metric: 0.752
# Early stopping, best iteration is:
# [116]	valid's binary_logloss: 0.447064	valid's Opt metric: 0.770492
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.442442	valid's Opt metric: 0.711864
# [200]	valid's binary_logloss: 0.375742	valid's Opt metric: 0.747967
# [300]	valid's binary_logloss: 0.352281	valid's Opt metric: 0.761905
# [400]	valid's binary_logloss: 0.343278	valid's Opt metric: 0.784
# [500]	valid's binary_logloss: 0.337365	valid's Opt metric: 0.774194
# Early stopping, best iteration is:
# [343]	valid's binary_logloss: 0.347173	valid's Opt metric: 0.784
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.443924	valid's Opt metric: 0.728814
# [200]	valid's binary_logloss: 0.371463	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.349657	valid's Opt metric: 0.768
# [400]	valid's binary_logloss: 0.341657	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.336654	valid's Opt metric: 0.8125
# [600]	valid's binary_logloss: 0.333315	valid's Opt metric: 0.793651
# Early stopping, best iteration is:
# [476]	valid's binary_logloss: 0.338377	valid's Opt metric: 0.8125
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.44609	valid's Opt metric: 0.739496
# [200]	valid's binary_logloss: 0.373823	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.348156	valid's Opt metric: 0.764228
# [400]	valid's binary_logloss: 0.338285	valid's Opt metric: 0.784
# [500]	valid's binary_logloss: 0.332117	valid's Opt metric: 0.784
# [600]	valid's binary_logloss: 0.333021	valid's Opt metric: 0.793651
# [700]	valid's binary_logloss: 0.333283	valid's Opt metric: 0.80315
# Early stopping, best iteration is:
# [542]	valid's binary_logloss: 0.330933	valid's Opt metric: 0.80315
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.463344	valid's Opt metric: 0.728814
# [200]	valid's binary_logloss: 0.394138	valid's Opt metric: 0.752
# [300]	valid's binary_logloss: 0.362975	valid's Opt metric: 0.752
# Early stopping, best iteration is:
# [145]	valid's binary_logloss: 0.42251	valid's Opt metric: 0.764228
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.448131	valid's Opt metric: 0.733333
# [200]	valid's binary_logloss: 0.379733	valid's Opt metric: 0.752
# [300]	valid's binary_logloss: 0.355114	valid's Opt metric: 0.752
# [400]	valid's binary_logloss: 0.346818	valid's Opt metric: 0.768
# [500]	valid's binary_logloss: 0.341639	valid's Opt metric: 0.774194
# [600]	valid's binary_logloss: 0.34497	valid's Opt metric: 0.774194
# [700]	valid's binary_logloss: 0.344569	valid's Opt metric: 0.774194
# Early stopping, best iteration is:
# [506]	valid's binary_logloss: 0.341713	valid's Opt metric: 0.784
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.456931	valid's Opt metric: 0.760331
# [200]	valid's binary_logloss: 0.383805	valid's Opt metric: 0.764228
# [300]	valid's binary_logloss: 0.351142	valid's Opt metric: 0.758065
# Early stopping, best iteration is:
# [116]	valid's binary_logloss: 0.441649	valid's Opt metric: 0.770492
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.447615	valid's Opt metric: 0.739496
# [200]	valid's binary_logloss: 0.374723	valid's Opt metric: 0.741935
# [300]	valid's binary_logloss: 0.349161	valid's Opt metric: 0.754098
# [400]	valid's binary_logloss: 0.33937	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.336464	valid's Opt metric: 0.80315
# [600]	valid's binary_logloss: 0.333823	valid's Opt metric: 0.8125
# [700]	valid's binary_logloss: 0.337111	valid's Opt metric: 0.821705
# Early stopping, best iteration is:
# [557]	valid's binary_logloss: 0.332468	valid's Opt metric: 0.8125
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.442695	valid's Opt metric: 0.733333
# [200]	valid's binary_logloss: 0.372894	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.348915	valid's Opt metric: 0.777778
# [400]	valid's binary_logloss: 0.339984	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.335918	valid's Opt metric: 0.80315
# [600]	valid's binary_logloss: 0.335437	valid's Opt metric: 0.8125
# [700]	valid's binary_logloss: 0.337358	valid's Opt metric: 0.821705
# Early stopping, best iteration is:
# [515]	valid's binary_logloss: 0.335215	valid's Opt metric: 0.821705
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.441905	valid's Opt metric: 0.733333
# [200]	valid's binary_logloss: 0.372726	valid's Opt metric: 0.747967
# [300]	valid's binary_logloss: 0.351519	valid's Opt metric: 0.768
# [400]	valid's binary_logloss: 0.342102	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.337364	valid's Opt metric: 0.793651
# [600]	valid's binary_logloss: 0.333907	valid's Opt metric: 0.80315
# [700]	valid's binary_logloss: 0.334039	valid's Opt metric: 0.8125
# Early stopping, best iteration is:
# [550]	valid's binary_logloss: 0.333943	valid's Opt metric: 0.8125
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.442411	valid's Opt metric: 0.743802
# [200]	valid's binary_logloss: 0.373061	valid's Opt metric: 0.747967
# [300]	valid's binary_logloss: 0.3495	valid's Opt metric: 0.774194
# [400]	valid's binary_logloss: 0.342213	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.33479	valid's Opt metric: 0.793651
# [600]	valid's binary_logloss: 0.333652	valid's Opt metric: 0.793651
# Early stopping, best iteration is:
# [432]	valid's binary_logloss: 0.340526	valid's Opt metric: 0.80315
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.440907	valid's Opt metric: 0.743802
# [200]	valid's binary_logloss: 0.372367	valid's Opt metric: 0.741935
# [300]	valid's binary_logloss: 0.351621	valid's Opt metric: 0.774194
# [400]	valid's binary_logloss: 0.343138	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.339678	valid's Opt metric: 0.793651
# [600]	valid's binary_logloss: 0.340074	valid's Opt metric: 0.8125
# [700]	valid's binary_logloss: 0.341498	valid's Opt metric: 0.8125
# Early stopping, best iteration is:
# [530]	valid's binary_logloss: 0.337736	valid's Opt metric: 0.821705
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.445137	valid's Opt metric: 0.722689
# [200]	valid's binary_logloss: 0.373843	valid's Opt metric: 0.752
# [300]	valid's binary_logloss: 0.347699	valid's Opt metric: 0.752
# [400]	valid's binary_logloss: 0.336181	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.329575	valid's Opt metric: 0.793651
# [600]	valid's binary_logloss: 0.327118	valid's Opt metric: 0.793651
# [700]	valid's binary_logloss: 0.32761	valid's Opt metric: 0.80315
# Early stopping, best iteration is:
# [590]	valid's binary_logloss: 0.326059	valid's Opt metric: 0.793651
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.43586	valid's Opt metric: 0.716667
# [200]	valid's binary_logloss: 0.374659	valid's Opt metric: 0.752
# [300]	valid's binary_logloss: 0.353725	valid's Opt metric: 0.758065
# [400]	valid's binary_logloss: 0.342566	valid's Opt metric: 0.784
# [500]	valid's binary_logloss: 0.339685	valid's Opt metric: 0.793651
# [600]	valid's binary_logloss: 0.335228	valid's Opt metric: 0.793651
# Early stopping, best iteration is:
# [439]	valid's binary_logloss: 0.341853	valid's Opt metric: 0.80315
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.437521	valid's Opt metric: 0.722689
# [200]	valid's binary_logloss: 0.372963	valid's Opt metric: 0.752
# [300]	valid's binary_logloss: 0.353639	valid's Opt metric: 0.774194
# [400]	valid's binary_logloss: 0.344843	valid's Opt metric: 0.784
# [500]	valid's binary_logloss: 0.342345	valid's Opt metric: 0.793651
# [600]	valid's binary_logloss: 0.340561	valid's Opt metric: 0.8125
# [700]	valid's binary_logloss: 0.339136	valid's Opt metric: 0.80315
# Early stopping, best iteration is:
# [598]	valid's binary_logloss: 0.340507	valid's Opt metric: 0.8125
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.442488	valid's Opt metric: 0.711864
# [200]	valid's binary_logloss: 0.375272	valid's Opt metric: 0.741935
# [300]	valid's binary_logloss: 0.351671	valid's Opt metric: 0.761905
# [400]	valid's binary_logloss: 0.341649	valid's Opt metric: 0.784
# [500]	valid's binary_logloss: 0.33596	valid's Opt metric: 0.774194
# Early stopping, best iteration is:
# [336]	valid's binary_logloss: 0.347244	valid's Opt metric: 0.784
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.49535	valid's Opt metric: 0.706897
# [200]	valid's binary_logloss: 0.437258	valid's Opt metric: 0.716667
# [300]	valid's binary_logloss: 0.412687	valid's Opt metric: 0.731707
# [400]	valid's binary_logloss: 0.399695	valid's Opt metric: 0.741935
# [500]	valid's binary_logloss: 0.391267	valid's Opt metric: 0.752
# [600]	valid's binary_logloss: 0.385674	valid's Opt metric: 0.752
# [700]	valid's binary_logloss: 0.379767	valid's Opt metric: 0.761905
# [800]	valid's binary_logloss: 0.374152	valid's Opt metric: 0.761905
# Early stopping, best iteration is:
# [630]	valid's binary_logloss: 0.384134	valid's Opt metric: 0.761905
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.440452	valid's Opt metric: 0.722689
# [200]	valid's binary_logloss: 0.371568	valid's Opt metric: 0.741935
# [300]	valid's binary_logloss: 0.351639	valid's Opt metric: 0.764228
# [400]	valid's binary_logloss: 0.34681	valid's Opt metric: 0.784
# [500]	valid's binary_logloss: 0.343353	valid's Opt metric: 0.8125
# [600]	valid's binary_logloss: 0.341185	valid's Opt metric: 0.8125
# [700]	valid's binary_logloss: 0.342517	valid's Opt metric: 0.80315
# Early stopping, best iteration is:
# [500]	valid's binary_logloss: 0.343353	valid's Opt metric: 0.8125
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.451647	valid's Opt metric: 0.75
# [200]	valid's binary_logloss: 0.378118	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.34834	valid's Opt metric: 0.758065
# Early stopping, best iteration is:
# [115]	valid's binary_logloss: 0.437597	valid's Opt metric: 0.770492
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.446405	valid's Opt metric: 0.739496
# [200]	valid's binary_logloss: 0.375902	valid's Opt metric: 0.764228
# [300]	valid's binary_logloss: 0.348041	valid's Opt metric: 0.758065
# [400]	valid's binary_logloss: 0.336331	valid's Opt metric: 0.784
# [500]	valid's binary_logloss: 0.329629	valid's Opt metric: 0.784
# [600]	valid's binary_logloss: 0.328654	valid's Opt metric: 0.793651
# [700]	valid's binary_logloss: 0.326672	valid's Opt metric: 0.80315
# Early stopping, best iteration is:
# [523]	valid's binary_logloss: 0.329029	valid's Opt metric: 0.80315
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.438708	valid's Opt metric: 0.737705
# [200]	valid's binary_logloss: 0.374485	valid's Opt metric: 0.752
# [300]	valid's binary_logloss: 0.35199	valid's Opt metric: 0.758065
# [400]	valid's binary_logloss: 0.341731	valid's Opt metric: 0.784
# [500]	valid's binary_logloss: 0.334084	valid's Opt metric: 0.793651
# [600]	valid's binary_logloss: 0.331521	valid's Opt metric: 0.793651
# Early stopping, best iteration is:
# [482]	valid's binary_logloss: 0.33562	valid's Opt metric: 0.793651
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.464369	valid's Opt metric: 0.711864
# [200]	valid's binary_logloss: 0.400876	valid's Opt metric: 0.741935
# [300]	valid's binary_logloss: 0.376337	valid's Opt metric: 0.752
# [400]	valid's binary_logloss: 0.364389	valid's Opt metric: 0.768
# [500]	valid's binary_logloss: 0.358153	valid's Opt metric: 0.758065
# Early stopping, best iteration is:
# [396]	valid's binary_logloss: 0.365592	valid's Opt metric: 0.768
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.45203	valid's Opt metric: 0.75
# [200]	valid's binary_logloss: 0.377599	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.34799	valid's Opt metric: 0.758065
# [400]	valid's binary_logloss: 0.336507	valid's Opt metric: 0.784
# [500]	valid's binary_logloss: 0.334995	valid's Opt metric: 0.793651
# [600]	valid's binary_logloss: 0.333803	valid's Opt metric: 0.830769
# [700]	valid's binary_logloss: 0.335512	valid's Opt metric: 0.830769
# Early stopping, best iteration is:
# [557]	valid's binary_logloss: 0.33254	valid's Opt metric: 0.8125
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.443923	valid's Opt metric: 0.728814
# [200]	valid's binary_logloss: 0.371719	valid's Opt metric: 0.752
# [300]	valid's binary_logloss: 0.350645	valid's Opt metric: 0.768
# [400]	valid's binary_logloss: 0.343107	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.339363	valid's Opt metric: 0.8125
# [600]	valid's binary_logloss: 0.337311	valid's Opt metric: 0.793651
# Early stopping, best iteration is:
# [477]	valid's binary_logloss: 0.340374	valid's Opt metric: 0.8125
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.442552	valid's Opt metric: 0.75
# [200]	valid's binary_logloss: 0.372639	valid's Opt metric: 0.752
# [300]	valid's binary_logloss: 0.34899	valid's Opt metric: 0.764228
# [400]	valid's binary_logloss: 0.338815	valid's Opt metric: 0.784
# [500]	valid's binary_logloss: 0.333102	valid's Opt metric: 0.793651
# ...
# [300]	valid's binary_logloss: 0.349062	valid's Opt metric: 0.784
# [400]	valid's binary_logloss: 0.338959	valid's Opt metric: 0.784
# [500]	valid's binary_logloss: 0.335101	valid's Opt metric: 0.8125
# [600]	valid's binary_logloss: 0.332536	valid's Opt metric: 0.821705
# [700]	valid's binary_logloss: 0.332987	valid's Opt metric: 0.821705
# Early stopping, best iteration is:
# [505]	valid's binary_logloss: 0.335253	valid's Opt metric: 0.821705
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.451914	valid's Opt metric: 0.728814
# [200]	valid's binary_logloss: 0.381854	valid's Opt metric: 0.752
# [300]	valid's binary_logloss: 0.352516	valid's Opt metric: 0.761905
# [400]	valid's binary_logloss: 0.340809	valid's Opt metric: 0.768
# [500]	valid's binary_logloss: 0.335768	valid's Opt metric: 0.784
# [600]	valid's binary_logloss: 0.336804	valid's Opt metric: 0.784
# Early stopping, best iteration is:
# [451]	valid's binary_logloss: 0.338117	valid's Opt metric: 0.793651
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.443745	valid's Opt metric: 0.75
# [200]	valid's binary_logloss: 0.372939	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.348294	valid's Opt metric: 0.764228
# [400]	valid's binary_logloss: 0.337792	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.332241	valid's Opt metric: 0.784
# Early stopping, best iteration is:
# [324]	valid's binary_logloss: 0.344438	valid's Opt metric: 0.793651
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.445537	valid's Opt metric: 0.739496
# [200]	valid's binary_logloss: 0.374086	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.348191	valid's Opt metric: 0.774194
# [400]	valid's binary_logloss: 0.338358	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.332888	valid's Opt metric: 0.80315
# [600]	valid's binary_logloss: 0.33212	valid's Opt metric: 0.80315
# [700]	valid's binary_logloss: 0.330857	valid's Opt metric: 0.8125
# [800]	valid's binary_logloss: 0.329421	valid's Opt metric: 0.821705
# Early stopping, best iteration is:
# [660]	valid's binary_logloss: 0.331034	valid's Opt metric: 0.821705
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.444196	valid's Opt metric: 0.739496
# [200]	valid's binary_logloss: 0.373217	valid's Opt metric: 0.747967
# [300]	valid's binary_logloss: 0.347579	valid's Opt metric: 0.747967
# [400]	valid's binary_logloss: 0.340088	valid's Opt metric: 0.784
# [500]	valid's binary_logloss: 0.332885	valid's Opt metric: 0.784
# [600]	valid's binary_logloss: 0.331602	valid's Opt metric: 0.80315
# [700]	valid's binary_logloss: 0.334367	valid's Opt metric: 0.793651
# Early stopping, best iteration is:
# [512]	valid's binary_logloss: 0.332187	valid's Opt metric: 0.80315
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.440537	valid's Opt metric: 0.743802
# [200]	valid's binary_logloss: 0.372622	valid's Opt metric: 0.752
# [300]	valid's binary_logloss: 0.351752	valid's Opt metric: 0.774194
# [400]	valid's binary_logloss: 0.345102	valid's Opt metric: 0.784
# [500]	valid's binary_logloss: 0.343761	valid's Opt metric: 0.784
# Early stopping, best iteration is:
# [318]	valid's binary_logloss: 0.350396	valid's Opt metric: 0.784
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.456584	valid's Opt metric: 0.733333
# [200]	valid's binary_logloss: 0.389996	valid's Opt metric: 0.752
# [300]	valid's binary_logloss: 0.362347	valid's Opt metric: 0.752
# Early stopping, best iteration is:
# [150]	valid's binary_logloss: 0.414671	valid's Opt metric: 0.754098
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.445437	valid's Opt metric: 0.739496
# [200]	valid's binary_logloss: 0.373546	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.348381	valid's Opt metric: 0.784
# [400]	valid's binary_logloss: 0.338974	valid's Opt metric: 0.80315
# [500]	valid's binary_logloss: 0.336072	valid's Opt metric: 0.8125
# [600]	valid's binary_logloss: 0.336231	valid's Opt metric: 0.8125
# [700]	valid's binary_logloss: 0.339239	valid's Opt metric: 0.8125
# Early stopping, best iteration is:
# [510]	valid's binary_logloss: 0.336122	valid's Opt metric: 0.821705
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.446642	valid's Opt metric: 0.739496
# [200]	valid's binary_logloss: 0.375002	valid's Opt metric: 0.747967
# [300]	valid's binary_logloss: 0.348972	valid's Opt metric: 0.764228
# [400]	valid's binary_logloss: 0.340867	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.338027	valid's Opt metric: 0.8125
# [600]	valid's binary_logloss: 0.337397	valid's Opt metric: 0.8125
# [700]	valid's binary_logloss: 0.338235	valid's Opt metric: 0.821705
# Early stopping, best iteration is:
# [558]	valid's binary_logloss: 0.336751	valid's Opt metric: 0.830769
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.445115	valid's Opt metric: 0.739496
# [200]	valid's binary_logloss: 0.372812	valid's Opt metric: 0.752
# [300]	valid's binary_logloss: 0.34738	valid's Opt metric: 0.764228
# [400]	valid's binary_logloss: 0.337981	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.335162	valid's Opt metric: 0.80315
# [600]	valid's binary_logloss: 0.330947	valid's Opt metric: 0.821705
# [700]	valid's binary_logloss: 0.331009	valid's Opt metric: 0.830769
# Early stopping, best iteration is:
# [591]	valid's binary_logloss: 0.330444	valid's Opt metric: 0.821705
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.445183	valid's Opt metric: 0.739496
# [200]	valid's binary_logloss: 0.374733	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.34827	valid's Opt metric: 0.774194
# [400]	valid's binary_logloss: 0.338331	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.333157	valid's Opt metric: 0.80315
# [600]	valid's binary_logloss: 0.332053	valid's Opt metric: 0.80315
# Early stopping, best iteration is:
# [430]	valid's binary_logloss: 0.334969	valid's Opt metric: 0.80315
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.450621	valid's Opt metric: 0.739496
# [200]	valid's binary_logloss: 0.381148	valid's Opt metric: 0.747967
# [300]	valid's binary_logloss: 0.353082	valid's Opt metric: 0.758065
# [400]	valid's binary_logloss: 0.343738	valid's Opt metric: 0.777778
# [500]	valid's binary_logloss: 0.336151	valid's Opt metric: 0.774194
# [600]	valid's binary_logloss: 0.335281	valid's Opt metric: 0.784
# Early stopping, best iteration is:
# [440]	valid's binary_logloss: 0.340316	valid's Opt metric: 0.793651
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.446716	valid's Opt metric: 0.739496
# [200]	valid's binary_logloss: 0.374797	valid's Opt metric: 0.747967
# [300]	valid's binary_logloss: 0.349063	valid's Opt metric: 0.754098
# [400]	valid's binary_logloss: 0.340271	valid's Opt metric: 0.774194
# [500]	valid's binary_logloss: 0.33913	valid's Opt metric: 0.793651
# [600]	valid's binary_logloss: 0.340584	valid's Opt metric: 0.793651
# Early stopping, best iteration is:
# [455]	valid's binary_logloss: 0.338315	valid's Opt metric: 0.784
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.442271	valid's Opt metric: 0.733333
# [200]	valid's binary_logloss: 0.371899	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.350246	valid's Opt metric: 0.774194
# [400]	valid's binary_logloss: 0.341936	valid's Opt metric: 0.784
# [500]	valid's binary_logloss: 0.338738	valid's Opt metric: 0.793651
# Early stopping, best iteration is:
# [305]	valid's binary_logloss: 0.34919	valid's Opt metric: 0.793651
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.445355	valid's Opt metric: 0.739496
# [200]	valid's binary_logloss: 0.372871	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.348395	valid's Opt metric: 0.774194
# [400]	valid's binary_logloss: 0.33884	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.336461	valid's Opt metric: 0.80315
# [600]	valid's binary_logloss: 0.335817	valid's Opt metric: 0.8125
# [700]	valid's binary_logloss: 0.338904	valid's Opt metric: 0.821705
# Early stopping, best iteration is:
# [511]	valid's binary_logloss: 0.336513	valid's Opt metric: 0.821705
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.446488	valid's Opt metric: 0.739496
# [200]	valid's binary_logloss: 0.374732	valid's Opt metric: 0.747967
# [300]	valid's binary_logloss: 0.348835	valid's Opt metric: 0.764228
# [400]	valid's binary_logloss: 0.339421	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.336877	valid's Opt metric: 0.80315
# [600]	valid's binary_logloss: 0.335378	valid's Opt metric: 0.821705
# [700]	valid's binary_logloss: 0.337299	valid's Opt metric: 0.830769
# [800]	valid's binary_logloss: 0.343444	valid's Opt metric: 0.821705
# Early stopping, best iteration is:
# [634]	valid's binary_logloss: 0.334474	valid's Opt metric: 0.8125
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.4499	valid's Opt metric: 0.75
# [200]	valid's binary_logloss: 0.377079	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.346861	valid's Opt metric: 0.758065
# Early stopping, best iteration is:
# [111]	valid's binary_logloss: 0.439264	valid's Opt metric: 0.770492
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.443386	valid's Opt metric: 0.75
# [200]	valid's binary_logloss: 0.372095	valid's Opt metric: 0.747967
# [300]	valid's binary_logloss: 0.347437	valid's Opt metric: 0.754098
# [400]	valid's binary_logloss: 0.338493	valid's Opt metric: 0.793651
# [500]	valid's binary_logloss: 0.331619	valid's Opt metric: 0.784
# Early stopping, best iteration is:
# [366]	valid's binary_logloss: 0.340192	valid's Opt metric: 0.793651
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 200 rounds
# [100]	valid's binary_logloss: 0.446015	valid's Opt metric: 0.733333
# [200]	valid's binary_logloss: 0.374363	valid's Opt metric: 0.758065
# [300]	valid's binary_logloss: 0.348139	valid's Opt metric: 0.758065
# [400]	valid's binary_logloss: 0.339344	valid's Opt metric: 0.784
# [500]	valid's binary_logloss: 0.332126	valid's Opt metric: 0.793651
# [600]	valid's binary_logloss: 0.330724	valid's Opt metric: 0.80315
# [700]	valid's binary_logloss: 0.330611	valid's Opt metric: 0.80315
# Early stopping, best iteration is:
# [581]	valid's binary_logloss: 0.329295	valid's Opt metric: 0.80315
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Start fitting Lvl_0_Pipe_1_Mod_1_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.326029	valid's Opt metric: 0.784
# [200]	valid's binary_logloss: 0.343894	valid's Opt metric: 0.821705
# Early stopping, best iteration is:
# [114]	valid's binary_logloss: 0.325053	valid's Opt metric: 0.821705
#
# ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.424118	valid's Opt metric: 0.753846
# Early stopping, best iteration is:
# [73]	valid's binary_logloss: 0.416476	valid's Opt metric: 0.748092
#
# ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.442906	valid's Opt metric: 0.734375
# Early stopping, best iteration is:
# [65]	valid's binary_logloss: 0.432367	valid's Opt metric: 0.715447
#
# ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.397209	valid's Opt metric: 0.776119
# Early stopping, best iteration is:
# [29]	valid's binary_logloss: 0.44483	valid's Opt metric: 0.8
#
# ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_1_LightGBM =====
#
# Training until validation scores don't improve for 100 rounds
# [100]	valid's binary_logloss: 0.387641	valid's Opt metric: 0.80303
# Early stopping, best iteration is:
# [72]	valid's binary_logloss: 0.37974	valid's Opt metric: 0.818182
# Lvl_0_Pipe_1_Mod_1_LightGBM fitting and predicting completed
# Time left 278.671599149704
# Blending: Optimization starts with equal weights and score 0.7658227848101266
# Blending, iter 0: score = 0.7762128325508606, weights = [0.15745492 0.         0.8425451 ]
# Blending, iter 1: score = 0.7685039370078741, weights = [0.15745492 0.         0.8425451 ]
# No score update. Terminated
#
# Automl preset training completed in 321.51 seconds.

# %%
test_pred[:5]
# Out:
# array([[0.15259145],
#        [0.35175982],
#        [0.10634716],
#        [0.14114384],
#        [0.7624237 ]], dtype=float32)

# %% [markdown]
# ## Prepare submission for Kaggle

# %%
submission['Survived'] = (test_pred.data[:, 0] > 0.5).astype(int)

print(submission.head())

submission.to_csv('submission/automl_utilized_600_f1_score.csv', index = False)
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1

# %%
# !head -n10 submission/automl_utilized_600_f1_score.csv
# Out:
# PassengerId,Survived
# 892,0
# 893,0
# 894,0
# 895,0
# 896,1
# 897,0
# 898,1
# 899,0
# 900,1
